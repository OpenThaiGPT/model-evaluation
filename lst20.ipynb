# %%
# !pip install seqeval
# Out:
# Collecting seqeval
#   Using cached seqeval-1.2.2-py3-none-any.whl
# Requirement already satisfied: numpy>=1.14.0 in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from seqeval) (2.0.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from seqeval) (1.5.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from scikit-learn>=0.21.3->seqeval) (3.5.0)
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
import requests

class GeminiModel:
    def __init__(self, model_name, api_key):
        """
        Initializes the GeminiModel class with the provided model name and API key.
        """
        self.model_name = model_name
        self.api_key = api_key

    def inference(self, prompt):
        """
        Performs inference using the Gemini model with the provided prompt.
        Returns the generated text response.
        """
        # print(self.model_name, self.api_key)
        
        headers = {
            "Content-Type": "application/json",
        }

        data = {"contents": [{"parts": [{"text": prompt}]}]}

        response = requests.post(
            f"https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?key={self.api_key}",
            headers=headers,
            json=data,
        )

        resp = response.json()
        # print(resp)

        # Extract and return the generated content
        return resp["candidates"][0]["content"]["parts"][0]["text"]

# %%
# Initialize the model
gemini = GeminiModel(model_name="gemini-1.5-flash", api_key="AIzaSyAOVySmLVyqnMgw7PXkiADdButH1Hzgijs")

# Perform inference
response = gemini.inference(prompt="Hello, how are you?")
print(response)
# Out:
# I am well, thank you for asking. How are you doing today?

# %%
# !gdown --fuzzy "https://drive.google.com/file/d/1ljktFM5mdSQoX0vCNgKqNf6uXzUbU_xe/view?usp=drive_link"
# Out:
# 'gdown' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import argparse
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification
from datasets import load_dataset
from seqeval.metrics import classification_report
from tqdm import tqdm

# %%
dataset = load_dataset("lst-nectec/lst20", split="test", data_dir="D:\Google Drive Mirroring\SuperAI\MT@LST-NECTEC\lst20\LST20_Corpus")

# %%
dataset.features[f"ner_tags"].feature
# Out:
# ClassLabel(names=['O', 'B_BRN', 'B_DES', 'B_DTM', 'B_LOC', 'B_MEA', 'B_NUM', 'B_ORG', 'B_PER', 'B_TRM', 'B_TTL', 'I_BRN', 'I_DES', 'I_DTM', 'I_LOC', 'I_MEA', 'I_NUM', 'I_ORG', 'I_PER', 'I_TRM', 'I_TTL', 'E_BRN', 'E_DES', 'E_DTM', 'E_LOC', 'E_MEA', 'E_NUM', 'E_ORG', 'E_PER', 'E_TRM', 'E_TTL'], id=None)

# %%
prompt = """\
You are an NER (Named Entity Recognition) token classification assistant. Your task is to classify each token in the provided text using the following NER tags:

['O', 'B_BRN', 'B_DES', 'B_DTM', 'B_LOC', 'B_MEA', 'B_NUM', 'B_ORG', 'B_PER', 'B_TRM', 'B_TTL', 
 'I_BRN', 'I_DES', 'I_DTM', 'I_LOC', 'I_MEA', 'I_NUM', 'I_ORG', 'I_PER', 'I_TRM', 'I_TTL', 
 'E_BRN', 'E_DES', 'E_DTM', 'E_LOC', 'E_MEA', 'E_NUM', 'E_ORG', 'E_PER', 'E_TRM', 'E_TTL']

### NER Tag Definitions:
- **B_XXX**: Beginning of an entity (e.g., B_PER for a person’s name).
- **I_XXX**: Inside an entity.
- **E_XXX**: End of an entity.
- **O**: Other (not part of any entity).

### Entity Type Glossary:
- **O**: Not an entity
- **BRN**: Brand
- **DES**: Description
- **DTM**: Date/Time
- **LOC**: Location
- **MEA**: Measurement
- **NUM**: Number
- **ORG**: Organization
- **PER**: Person
- **TRM**: Term
- **TTL**: Title

### Classification Instructions:
1. **Analyze Context**: Use the surrounding sentence context to accurately classify tokens.
2. **Multi-Token Entities**: For entities spanning multiple tokens:
   - Start with **B_XXX** for the first token,
   - Use **I_XXX** for subsequent tokens,
   - Use **E_XXX** for the final token (if applicable).
3. **Non-Entity Tokens**: Label tokens as **O** if they are not part of any entity.
4. **Consistency**: Ensure classifications are consistent with nearby tokens.
5. **Space Handling**: The character `_` represents a space and should be treated as part of a token, especially for multi-word names.
6. **Equal Length**: The input and output should contain the same number of elements.

---

### Input Format:
`[token1, token2, token3, ..., tokenN]`

### Output Format:
`[(token1, label1), (token2, label2), ..., (tokenN, labelN)]`

---

### Example Input Tokens:
['ซึ่ง', 'นาย', 'อภิชาต', '_', 'สุขัคคานนท์', 'ประธาน', 'กกต.', ...]

### Expected Output:
[('ซึ่ง', 'O'), ('นาย', 'B_TTL'), ('อภิชาต', 'B_PER'), ('_', 'I_PER'), ('สุขัคคานนท์', 'E_PER'), ('ประธาน', 'O'), ('กกต.', 'B_ORG'), ...]

### Explanation:
- **อภิชาต สุขัคคานนท์** is a person, tagged as `B_PER`, `I_PER`, and `E_PER`.
- **กกต.** is an organization, tagged as `B_ORG`.
- Non-entity tokens like **ได้** are labeled as `O`.
- The character `_` represents a space in multi-word entities.

---

### Classify the following tokens:
{}

Answer:
"""

# %%
import ast

results = []

ds = dataset.select(range(100))

for item in tqdm(ds, total=len(ds)):
    labels = [dataset.features["ner_tags"].feature.int2str(idx) for idx in item["ner_tags"]]
    try:
        response = gemini.inference(prompt=prompt.format(item["tokens"]))
        results.append({
            "tokens": item["tokens"],
            "label": labels,
            "pred": ast.literal_eval(response)
        })
    except KeyError:
        pass
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [11:17<00:00,  6.77s/it]

# %%
results
# Out:
# [{'tokens': ['จีน',
#    '-',
#    'อินเดีย',
#    'เสี่ยง',
#    'สูญเสีย',
#    'จาก',
#    'ภัย',
#    'ธรรมชาติ',
#    'มาก',
#    'สุด'],
#   'label': ['B_LOC', 'O', 'B_LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'pred': [('จีน', 'B_LOC'),
#    ('-', 'O'),
#    ('อินเดีย', 'B_LOC'),
#    ('เสี่ยง', 'O'),
#    ('สูญเสีย', 'O'),
#    ('จาก', 'O'),
#    ('ภัย', 'B_DES'),
#    ('ธรรมชาติ', 'E_DES'),
#    ('มาก', 'O'),
#    ('สุด', 'O')]},
#  {'tokens': ['เจนีวา',
#    '_',
#    '-',
#    '_',
#    'จีน',
#    '_',
#    'อินเดีย',
#    '_',
#    'และ',
#    'ประเทศ',
#    'ที่',
#    'มี',
#    'ประชากร',
#    'จำนวน',
#    'มาก',
#    '_',
#    'ติด',
#    'อยู่',
#    'ใน',
#    'กลุ่ม',
#    'ย่ำแย่',
#    'สุด',
#    '_',
#    'ของ',
#    'การ',
#    'จัด',
#    'ค่า',
#    'เฉลี่ย',
#    'ความ',
#    'เสี่ยง',
#    'จาก',
#    'ภัย',
#    'ธรรมชาติ'],
#   'label': ['B_LOC',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('เจนีวา', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('-', 'O'),
#    ('_', 'O'),
#    ('จีน', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('อินเดีย', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('และ', 'O'),
#    ('ประเทศ', 'B_LOC'),
#    ('ที่', 'O'),
#    ('มี', 'O'),
#    ('ประชากร', 'O'),
#    ('จำนวน', 'O'),
#    ('มาก', 'O'),
#    ('_', 'O'),
#    ('ติด', 'O'),
#    ('อยู่', 'O'),
#    ('ใน', 'O'),
#    ('กลุ่ม', 'O'),
#    ('ย่ำแย่', 'O'),
#    ('สุด', 'O'),
#    ('_', 'O'),
#    ('ของ', 'O'),
#    ('การ', 'O'),
#    ('จัด', 'O'),
#    ('ค่า', 'O'),
#    ('เฉลี่ย', 'O'),
#    ('ความ', 'O'),
#    ('เสี่ยง', 'O'),
#    ('จาก', 'O'),
#    ('ภัย', 'O'),
#    ('ธรรมชาติ', 'O')]},
#  {'tokens': ['ใน',
#    'รายงาน',
#    'ความ',
#    'เสี่ยง',
#    'จาก',
#    'ภัย',
#    'ธรรมชาติ',
#    '_',
#    'ที่',
#    'เกี่ยวข้อง',
#    'กับ',
#    'ขนาด',
#    'ของ',
#    'ประชากร',
#    '_',
#    'ซึ่ง',
#    'สหประชาชาติ',
#    '_',
#    '(',
#    'ยูเอ็น',
#    ')',
#    '_',
#    'เผย',
#    'เมื่อ',
#    'วัน',
#    'จันทร์',
#    '_',
#    '(',
#    '15',
#    '_',
#    'มิ.ย.',
#    ')',
#    '_',
#    'ยัง',
#    'พบ',
#    'ว่า',
#    '_',
#    'ประเทศ',
#    '_',
#    'และ',
#    'หมู่เกาะ',
#    '_',
#    'ที่',
#    'มี',
#    'ขนาด',
#    'เล็ก',
#    '_',
#    'อย่าง',
#    '_',
#    'โคลัมเบีย',
#    '_',
#    'และ',
#    'พม่า',
#    '_',
#    'อยู่',
#    'ใน',
#    'กลุ่ม',
#    '_',
#    '"',
#    'ความ',
#    'เสี่ยง',
#    'สูง',
#    '"'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_ORG',
#    'O',
#    'O',
#    'B_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_DTM',
#    'E_DTM',
#    'O',
#    'O',
#    'B_DTM',
#    'I_DTM',
#    'E_DTM',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('ใน', 'O'),
#    ('รายงาน', 'O'),
#    ('ความ', 'O'),
#    ('เสี่ยง', 'O'),
#    ('จาก', 'O'),
#    ('ภัย', 'O'),
#    ('ธรรมชาติ', 'O'),
#    ('_', 'O'),
#    ('ที่', 'O'),
#    ('เกี่ยวข้อง', 'O'),
#    ('กับ', 'O'),
#    ('ขนาด', 'O'),
#    ('ของ', 'O'),
#    ('ประชากร', 'O'),
#    ('_', 'O'),
#    ('ซึ่ง', 'O'),
#    ('สหประชาชาติ', 'B_ORG'),
#    ('_', 'I_ORG'),
#    ('(', 'O'),
#    ('ยูเอ็น', 'E_ORG'),
#    (')', 'O'),
#    ('_', 'O'),
#    ('เผย', 'O'),
#    ('เมื่อ', 'O'),
#    ('วัน', 'O'),
#    ('จันทร์', 'O'),
#    ('_', 'O'),
#    ('(', 'O'),
#    ('15', 'B_NUM'),
#    ('_', 'I_NUM'),
#    ('มิ.ย.', 'E_NUM'),
#    (')', 'O'),
#    ('_', 'O'),
#    ('ยัง', 'O'),
#    ('พบ', 'O'),
#    ('ว่า', 'O'),
#    ('_', 'O'),
#    ('ประเทศ', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('หมู่เกาะ', 'O'),
#    ('_', 'O'),
#    ('ที่', 'O'),
#    ('มี', 'O'),
#    ('ขนาด', 'O'),
#    ('เล็ก', 'O'),
#    ('_', 'O'),
#    ('อย่าง', 'O'),
#    ('_', 'O'),
#    ('โคลัมเบีย', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('และ', 'O'),
#    ('พม่า', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('อยู่', 'O'),
#    ('ใน', 'O'),
#    ('กลุ่ม', 'O'),
#    ('_', 'O'),
#    ('"', 'O'),
#    ('ความ', 'O'),
#    ('เสี่ยง', 'O'),
#    ('สูง', 'O'),
#    ('"', 'O')]},
#  {'tokens': ['ประชากร',
#    'กลุ่ม',
#    'เสี่ยง',
#    'ส่วนใหญ่',
#    '_',
#    'อาศัย',
#    'อยู่',
#    'ใกล้',
#    'กับ',
#    'แหล่ง',
#    'น้ำ',
#    '_',
#    'บ่งชี้',
#    'ว่า',
#    '_',
#    'อาจ',
#    'เป็น',
#    'ผล',
#    'จาก',
#    'ภาวะ',
#    'โลก',
#    'ร้อน',
#    'ที่',
#    'รุนแรง',
#    'ขึ้น',
#    '_',
#    'ซึ่ง',
#    'สร้าง',
#    'ความ',
#    'เสียหาย',
#    'ให้',
#    'กับ',
#    'รูปแบบ',
#    'ของ',
#    'สภาพ',
#    'อากาศ'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('ประชากร', 'O'),
#    ('กลุ่ม', 'O'),
#    ('เสี่ยง', 'O'),
#    ('ส่วนใหญ่', 'O'),
#    ('_', 'O'),
#    ('อาศัย', 'O'),
#    ('อยู่', 'O'),
#    ('ใกล้', 'O'),
#    ('กับ', 'O'),
#    ('แหล่ง', 'O'),
#    ('น้ำ', 'O'),
#    ('_', 'O'),
#    ('บ่งชี้', 'O'),
#    ('ว่า', 'O'),
#    ('_', 'O'),
#    ('อาจ', 'O'),
#    ('เป็น', 'O'),
#    ('ผล', 'O'),
#    ('จาก', 'O'),
#    ('ภาวะ', 'O'),
#    ('โลก', 'B_LOC'),
#    ('ร้อน', 'E_LOC'),
#    ('ที่', 'B_DES'),
#    ('รุนแรง', 'I_DES'),
#    ('ขึ้น', 'E_DES'),
#    ('_', 'O'),
#    ('ซึ่ง', 'O'),
#    ('สร้าง', 'O'),
#    ('ความ', 'O'),
#    ('เสียหาย', 'O'),
#    ('ให้', 'O'),
#    ('กับ', 'O'),
#    ('รูปแบบ', 'O'),
#    ('ของ', 'O'),
#    ('สภาพ', 'O'),
#    ('อากาศ', 'O')]},
#  {'tokens': ['เกิด',
#    'เหตุ',
#    'พายุ',
#    'พัด',
#    'ถล่ม',
#    'จีน',
#    '_',
#    'ทำให้',
#    'มี',
#    'ผู้',
#    'เสียชีวิต',
#    'อย่าง',
#    'น้อย',
#    '_',
#    '14',
#    '_',
#    'คน',
#    '_',
#    'และ',
#    'ไร้',
#    'ที่อยู่อาศัย',
#    'จำนวน',
#    'มาก'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_NUM',
#    'O',
#    'B_MEA',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('เกิด', 'O'),
#    ('เหตุ', 'O'),
#    ('พายุ', 'O'),
#    ('พัด', 'O'),
#    ('ถล่ม', 'O'),
#    ('จีน', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('ทำให้', 'O'),
#    ('มี', 'O'),
#    ('ผู้', 'O'),
#    ('เสียชีวิต', 'O'),
#    ('อย่าง', 'O'),
#    ('น้อย', 'O'),
#    ('_', 'O'),
#    ('14', 'B_NUM'),
#    ('_', 'I_NUM'),
#    ('คน', 'E_NUM'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('ไร้', 'O'),
#    ('ที่อยู่อาศัย', 'O'),
#    ('จำนวน', 'O'),
#    ('มาก', 'O')]},
#  {'tokens': ['เกิด',
#    'เหตุ',
#    'พายุ',
#    'พัด',
#    'ถล่ม',
#    'ภาค',
#    'ตะวันออก',
#    'ของ',
#    'ประเทศ',
#    'จีน',
#    'ทำให้',
#    'มี',
#    'ผู้',
#    'เสียชีวิต',
#    'แล้ว',
#    'อย่าง',
#    'น้อย',
#    '_',
#    '14',
#    '_',
#    'คน',
#    'บาดเจ็บ',
#    'อีก',
#    'มาก',
#    'กว่า',
#    '_',
#    '180',
#    '_',
#    'คน',
#    '_',
#    'และ',
#    'บ้านเรือน',
#    'ประชาชน',
#    'ใน',
#    'มณฑลอานฮุย',
#    'หลาย',
#    'พัน',
#    'หลัง',
#    'ได้รับ',
#    'ความ',
#    'เสียหาย'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_NUM',
#    'O',
#    'B_MEA',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_NUM',
#    'O',
#    'B_MEA',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'B_MEA',
#    'E_MEA',
#    'O',
#    'O',
#    'O'],
#   'pred': [('เกิด', 'O'),
#    ('เหตุ', 'O'),
#    ('พายุ', 'B_TRM'),
#    ('พัด', 'O'),
#    ('ถล่ม', 'O'),
#    ('ภาค', 'B_LOC'),
#    ('ตะวันออก', 'I_LOC'),
#    ('ของ', 'O'),
#    ('ประเทศ', 'B_LOC'),
#    ('จีน', 'I_LOC'),
#    ('ทำให้', 'O'),
#    ('มี', 'O'),
#    ('ผู้', 'B_PER'),
#    ('เสียชีวิต', 'O'),
#    ('แล้ว', 'O'),
#    ('อย่าง', 'O'),
#    ('น้อย', 'B_MEA'),
#    ('_', 'I_MEA'),
#    ('14', 'I_MEA'),
#    ('_', 'I_MEA'),
#    ('คน', 'E_MEA'),
#    ('บาดเจ็บ', 'O'),
#    ('อีก', 'O'),
#    ('มาก', 'O'),
#    ('กว่า', 'O'),
#    ('_', 'O'),
#    ('180', 'B_NUM'),
#    ('_', 'O'),
#    ('คน', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('บ้านเรือน', 'O'),
#    ('ประชาชน', 'B_PER'),
#    ('ใน', 'B_LOC'),
#    ('มณฑลอานฮุย', 'I_LOC'),
#    ('หลาย', 'B_MEA'),
#    ('พัน', 'I_MEA'),
#    ('หลัง', 'I_MEA'),
#    ('ได้รับ', 'O'),
#    ('ความ', 'O'),
#    ('เสียหาย', 'O')]},
#  {'tokens': ['สำนัก',
#    'กิจการ',
#    'พลเรือน',
#    'มณฑลอานฮุย',
#    '_',
#    'รายงาน',
#    'ว่า',
#    '_',
#    'เหตุ',
#    'พายุ',
#    'พัด',
#    'กระหน่ำ',
#    'มณฑลอานฮุย',
#    'ของ',
#    'จีน',
#    'วาน',
#    'นี้'],
#   'label': ['B_ORG',
#    'I_ORG',
#    'I_ORG',
#    'E_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'B_LOC',
#    'B_DTM',
#    'E_DTM'],
#   'pred': [('สำนัก', 'B_ORG'),
#    ('กิจการ', 'B_ORG'),
#    ('พลเรือน', 'E_ORG'),
#    ('มณฑลอานฮุย', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('รายงาน', 'O'),
#    ('ว่า', 'O'),
#    ('_', 'O'),
#    ('เหตุ', 'B_DES'),
#    ('พายุ', 'B_DES'),
#    ('พัด', 'B_DES'),
#    ('กระหน่ำ', 'I_DES'),
#    ('มณฑลอานฮุย', 'B_LOC'),
#    ('ของ', 'B_LOC'),
#    ('จีน', 'E_LOC'),
#    ('วาน', 'B_DTM'),
#    ('นี้', 'I_DTM')]},
#  {'tokens': ['ทำให้',
#    'ประชาชน',
#    'กว่า',
#    '_',
#    '10,000',
#    '_',
#    'คน',
#    '_',
#    'ต้อง',
#    'อพยพ',
#    'ออก',
#    'จาก',
#    'พื้นที่',
#    '_',
#    'อิทธิพล',
#    'ของ',
#    'พายุ',
#    'ยัง',
#    'ทำให้',
#    'บ้านเรือน',
#    'เกือบ',
#    '_',
#    '9,700',
#    '_',
#    'หลัง',
#    'พัง',
#    'ถล่ม',
#    'ลง',
#    'มา',
#    '_',
#    'สร้าง',
#    'ความ',
#    'เสียหาย',
#    'คิด',
#    'เป็น',
#    'มูลค่า',
#    '_',
#    '450',
#    '_',
#    'ล้าน',
#    'หยวน'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'B_NUM',
#    'O',
#    'B_MEA',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_MEA',
#    'O',
#    'B_MEA',
#    'E_MEA'],
#   'pred': [('ทำให้', 'O'),
#    ('ประชาชน', 'O'),
#    ('กว่า', 'O'),
#    ('_', 'O'),
#    ('10,000', 'B_NUM'),
#    ('_', 'I_NUM'),
#    ('คน', 'E_NUM'),
#    ('_', 'O'),
#    ('ต้อง', 'O'),
#    ('อพยพ', 'O'),
#    ('ออก', 'O'),
#    ('จาก', 'O'),
#    ('พื้นที่', 'O'),
#    ('_', 'O'),
#    ('อิทธิพล', 'O'),
#    ('ของ', 'O'),
#    ('พายุ', 'O'),
#    ('ยัง', 'O'),
#    ('ทำให้', 'O'),
#    ('บ้านเรือน', 'O'),
#    ('เกือบ', 'O'),
#    ('_', 'O'),
#    ('9,700', 'B_NUM'),
#    ('_', 'I_NUM'),
#    ('หลัง', 'E_NUM'),
#    ('พัง', 'O'),
#    ('ถล่ม', 'O'),
#    ('ลง', 'O'),
#    ('มา', 'O'),
#    ('_', 'O'),
#    ('สร้าง', 'O'),
#    ('ความ', 'O'),
#    ('เสียหาย', 'O'),
#    ('คิด', 'O'),
#    ('เป็น', 'O'),
#    ('มูลค่า', 'O'),
#    ('_', 'O'),
#    ('450', 'B_NUM'),
#    ('_', 'I_NUM'),
#    ('ล้าน', 'I_NUM'),
#    ('หยวน', 'E_NUM')]},
#  {'tokens': ['ขณะ',
#    'ที่',
#    '_',
#    'เจ้าหน้าที่',
#    'ท้องถิ่น',
#    'ได้',
#    'ออก',
#    'ประกาศ',
#    'เตือน',
#    'ให้',
#    'ประชาชน',
#    'เตรียม',
#    'พร้อม',
#    'รับ',
#    'ภัย',
#    'ธรรมชาติ',
#    'ครั้ง',
#    'นี้',
#    '_',
#    'เนื่องจาก',
#    'คาด',
#    'ว่า',
#    'สภาพ',
#    'อากาศ',
#    'จะ',
#    'เลวร้าย',
#    'ลง',
#    'อีก'],
#   'label': ['O',
#    'O',
#    'O',
#    'B_ORG',
#    'E_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('ขณะ', 'O'),
#    ('ที่', 'O'),
#    ('_', 'O'),
#    ('เจ้าหน้าที่', 'B_ORG'),
#    ('ท้องถิ่น', 'I_ORG'),
#    ('ได้', 'O'),
#    ('ออก', 'O'),
#    ('ประกาศ', 'O'),
#    ('เตือน', 'O'),
#    ('ให้', 'O'),
#    ('ประชาชน', 'B_PER'),
#    ('เตรียม', 'O'),
#    ('พร้อม', 'O'),
#    ('รับ', 'O'),
#    ('ภัย', 'B_DES'),
#    ('ธรรมชาติ', 'I_DES'),
#    ('ครั้ง', 'B_NUM'),
#    ('นี้', 'I_NUM'),
#    ('_', 'O'),
#    ('เนื่องจาก', 'O'),
#    ('คาด', 'O'),
#    ('ว่า', 'O'),
#    ('สภาพ', 'B_DES'),
#    ('อากาศ', 'I_DES'),
#    ('จะ', 'O'),
#    ('เลวร้าย', 'B_DES'),
#    ('ลง', 'O'),
#    ('อีก', 'O')]},
#  {'tokens': ['เชื่อน',
#    'จีน',
#    '_',
#    '40',
#    '%',
#    '_',
#    'เสี่ยง',
#    'ถล่ม',
#    '_',
#    'หลัง',
#    'สร้าง',
#    'ไม่',
#    'นาน'],
#   'label': ['O',
#    'B_LOC',
#    'O',
#    'B_MEA',
#    'E_MEA',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('เชื่อน', 'B_LOC'),
#    ('จีน', 'E_LOC'),
#    ('_', 'O'),
#    ('40', 'B_NUM'),
#    ('%', 'E_NUM'),
#    ('_', 'O'),
#    ('เสี่ยง', 'B_DES'),
#    ('ถล่ม', 'O'),
#    ('_', 'O'),
#    ('หลัง', 'O'),
#    ('สร้าง', 'O'),
#    ('ไม่', 'O'),
#    ('นาน', 'O')]},
#  {'tokens': ['ปักกิ่ง',
#    '_',
#    '-',
#    '_',
#    'สื่อ',
#    'มวล',
#    'ชน',
#    'จีน',
#    'ประโคม',
#    'ข่าว',
#    '_',
#    'เขื่อน',
#    'มาก',
#    'กว่า',
#    '_',
#    '40',
#    '%',
#    '_',
#    'ใน',
#    'ประเทศ',
#    '_',
#    'เสี่ยง',
#    'ที่',
#    'จะ',
#    'ถล่ม',
#    '_',
#    'ทั้ง',
#    'ที่',
#    'เพิ่ง',
#    'สร้าง',
#    'ได้',
#    'ไม่',
#    'กี่',
#    'ปี'],
#   'label': ['B_LOC',
#    'O',
#    'O',
#    'O',
#    'B_ORG',
#    'I_ORG',
#    'I_ORG',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_MEA',
#    'E_MEA',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('ปักกิ่ง', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('-', 'O'),
#    ('_', 'I_LOC'),
#    ('สื่อ', 'O'),
#    ('มวล', 'O'),
#    ('ชน', 'O'),
#    ('จีน', 'B_LOC'),
#    ('ประโคม', 'O'),
#    ('ข่าว', 'O'),
#    ('_', 'O'),
#    ('เขื่อน', 'O'),
#    ('มาก', 'O'),
#    ('กว่า', 'O'),
#    ('_', 'O'),
#    ('40', 'B_NUM'),
#    ('%', 'B_MEA'),
#    ('_', 'I_MEA'),
#    ('ใน', 'O'),
#    ('ประเทศ', 'O'),
#    ('_', 'O'),
#    ('เสี่ยง', 'O'),
#    ('ที่', 'O'),
#    ('จะ', 'O'),
#    ('ถล่ม', 'O'),
#    ('_', 'O'),
#    ('ทั้ง', 'O'),
#    ('ที่', 'O'),
#    ('เพิ่ง', 'O'),
#    ('สร้าง', 'O'),
#    ('ได้', 'O'),
#    ('ไม่', 'O'),
#    ('กี่', 'B_NUM'),
#    ('ปี', 'B_DTM'),
#    ('ปี', 'E_DTM')]},
#  {'tokens': ['หนังสือพิมพ์ไชน่า',
#    '_',
#    'เดลี่',
#    '_',
#    'ของ',
#    'ทางการ',
#    'จีน',
#    '_',
#    'รายงาน',
#    'ว่า',
#    '_',
#    'เขื่อน',
#    'หลาย',
#    'แห่ง',
#    'ที่',
#    'สร้าง',
#    'ไว้',
#    'ใน',
#    'บริเวณ',
#    'แม่น้ำเหลือง',
#    '_',
#    'กำลัง',
#    'ใกล้',
#    'จะ',
#    'พัง',
#    'ถล่ม',
#    'ลง',
#    'มา',
#    '_',
#    'หลัง',
#    'จาก',
#    'เพิ่ง',
#    'สร้าง',
#    'ได้',
#    'เพียง',
#    'ไม่',
#    'กี่',
#    'ปี',
#    '_',
#    'ท่ามกลาง',
#    'ความ',
#    'วิตก',
#    'ว่า',
#    'เขื่อน',
#    'ใน',
#    'ประเทศ',
#    'จีน',
#    'กว่า',
#    '_',
#    '40',
#    '_',
#    'เปอร์เซ็นต์',
#    '_',
#    'ไม่',
#    'มี',
#    'ความ',
#    'ปลอด',
#    'ภัย'],
#   'label': ['B_ORG',
#    'I_ORG',
#    'E_ORG',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'B_MEA',
#    'O',
#    'B_MEA',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('หนังสือพิมพ์ไชน่า', 'B_ORG'),
#    ('_', 'I_ORG'),
#    ('เดลี่', 'E_ORG'),
#    ('_', 'O'),
#    ('ของ', 'O'),
#    ('ทางการ', 'O'),
#    ('จีน', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('รายงาน', 'O'),
#    ('ว่า', 'O'),
#    ('_', 'O'),
#    ('เขื่อน', 'B_LOC'),
#    ('หลาย', 'O'),
#    ('แห่ง', 'O'),
#    ('ที่', 'O'),
#    ('สร้าง', 'O'),
#    ('ไว้', 'O'),
#    ('ใน', 'O'),
#    ('บริเวณ', 'O'),
#    ('แม่น้ำเหลือง', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('กำลัง', 'O'),
#    ('ใกล้', 'O'),
#    ('จะ', 'O'),
#    ('พัง', 'O'),
#    ('ถล่ม', 'O'),
#    ('ลง', 'O'),
#    ('มา', 'O'),
#    ('_', 'O'),
#    ('หลัง', 'O'),
#    ('จาก', 'O'),
#    ('เพิ่ง', 'O'),
#    ('สร้าง', 'O'),
#    ('ได้', 'O'),
#    ('เพียง', 'O'),
#    ('ไม่', 'O'),
#    ('กี่', 'O'),
#    ('ปี', 'B_DTM'),
#    ('_', 'I_DTM'),
#    ('ท่ามกลาง', 'O'),
#    ('ความ', 'O'),
#    ('วิตก', 'O'),
#    ('ว่า', 'O'),
#    ('เขื่อน', 'B_LOC'),
#    ('ใน', 'O'),
#    ('ประเทศ', 'B_LOC'),
#    ('จีน', 'I_LOC'),
#    ('กว่า', 'O'),
#    ('_', 'O'),
#    ('40', 'B_NUM'),
#    ('_', 'I_NUM'),
#    ('เปอร์เซ็นต์', 'E_NUM'),
#    ('_', 'O'),
#    ('ไม่', 'O'),
#    ('มี', 'O'),
#    ('ความ', 'O'),
#    ('ปลอด', 'O'),
#    ('ภัย', 'O')]},
#  {'tokens': ['รายงาน',
#    'ระบุ',
#    'ว่า',
#    '_',
#    'การ',
#    'ก่อสร้าง',
#    'ที่',
#    'ไร้',
#    'มาตรฐาน',
#    '_',
#    'ใช้',
#    'วัสดุ',
#    'คุณภาพ',
#    'ต่ำ',
#    '_',
#    'แรงงาน',
#    'ที่',
#    'ไม่',
#    'มี',
#    'คุณภาพ',
#    '_',
#    'และ',
#    'การ',
#    'ยักยอก',
#    'งบประมาณ',
#    'การ',
#    'ก่อสร้าง',
#    '_',
#    'ล้วน',
#    'เป็น',
#    'ปัจจัย',
#    'ที่',
#    'ทำให้',
#    'เขื่อน',
#    'ต่าง',
#    'ๆ',
#    '_',
#    'ใน',
#    'มณฑลกานซู',
#    '_',
#    'ตก',
#    'อยู่',
#    'ใน',
#    'ความ',
#    'เสี่ยง'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('รายงาน', 'O'),
#    ('ระบุ', 'O'),
#    ('ว่า', 'O'),
#    ('_', 'O'),
#    ('การ', 'O'),
#    ('ก่อสร้าง', 'O'),
#    ('ที่', 'O'),
#    ('ไร้', 'O'),
#    ('มาตรฐาน', 'O'),
#    ('_', 'O'),
#    ('ใช้', 'O'),
#    ('วัสดุ', 'O'),
#    ('คุณภาพ', 'O'),
#    ('ต่ำ', 'O'),
#    ('_', 'O'),
#    ('แรงงาน', 'O'),
#    ('ที่', 'O'),
#    ('ไม่', 'O'),
#    ('มี', 'O'),
#    ('คุณภาพ', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('การ', 'O'),
#    ('ยักยอก', 'O'),
#    ('งบประมาณ', 'O'),
#    ('การ', 'O'),
#    ('ก่อสร้าง', 'O'),
#    ('_', 'O'),
#    ('ล้วน', 'O'),
#    ('เป็น', 'O'),
#    ('ปัจจัย', 'O'),
#    ('ที่', 'O'),
#    ('ทำให้', 'O'),
#    ('เขื่อน', 'O'),
#    ('ต่าง', 'O'),
#    ('ๆ', 'O'),
#    ('_', 'O'),
#    ('ใน', 'O'),
#    ('มณฑลกานซู', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('ตก', 'O'),
#    ('อยู่', 'O'),
#    ('ใน', 'O'),
#    ('ความ', 'O'),
#    ('เสี่ยง', 'O')]},
#  {'tokens': ['สถานการณ์',
#    'นี้',
#    '_',
#    'ยัง',
#    'เป็น',
#    'ภัย',
#    'คุกคาม',
#    'อย่าง',
#    'มาก',
#    'ต่อ',
#    'ความ',
#    'ปลอด',
#    'ภัย',
#    'ของ',
#    'ประชาชน'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('สถานการณ์', 'O'),
#    ('นี้', 'O'),
#    ('_', 'O'),
#    ('ยัง', 'O'),
#    ('เป็น', 'O'),
#    ('ภัย', 'O'),
#    ('คุกคาม', 'O'),
#    ('อย่าง', 'O'),
#    ('มาก', 'O'),
#    ('ต่อ', 'O'),
#    ('ความ', 'O'),
#    ('ปลอด', 'O'),
#    ('ภัย', 'O'),
#    ('ของ', 'O'),
#    ('ประชาชน', 'O')]},
#  {'tokens': ['รายงาน',
#    'ข่าว',
#    'ดังกล่าว',
#    '_',
#    'ซึ่ง',
#    'อ้าง',
#    'การ',
#    'เข้า',
#    'ไป',
#    'ตรวจสอบ',
#    'ของ',
#    'หนังสือพิมพ์',
#    '_',
#    'ไชน่า',
#    '_',
#    'ยูธ',
#    '_',
#    'เดลี่',
#    '_',
#    'ยัง',
#    'ชี้',
#    'ให้',
#    'เห็น',
#    'ว่า',
#    '_',
#    'มี',
#    'เขื่อน',
#    'อยู่',
#    'แห่ง',
#    'หนึ่ง',
#    '_',
#    'ที่',
#    'เพิ่ง',
#    'สร้าง',
#    'เมื่อ',
#    'ปี',
#    '_',
#    '2539',
#    '_',
#    'ที่',
#    'เขต',
#    'หวน',
#    '_',
#    'บน',
#    'ฝั่ง',
#    'แม่น้ำเหลือง',
#    '_',
#    'กำลัง',
#    'มี',
#    'รอย',
#    'แตก',
#    'ใน',
#    'ระดับ',
#    'ที่',
#    'เป็น',
#    'อันตราย',
#    'บริเวณ',
#    'ช่วง',
#    'กลาง',
#    'ตัว',
#    'เชื่อน'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_ORG',
#    'I_ORG',
#    'I_ORG',
#    'I_ORG',
#    'I_ORG',
#    'I_ORG',
#    'E_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_DTM',
#    'I_DTM',
#    'E_DTM',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('รายงาน', 'O'),
#    ('ข่าว', 'O'),
#    ('ดังกล่าว', 'O'),
#    ('_', 'O'),
#    ('ซึ่ง', 'O'),
#    ('อ้าง', 'O'),
#    ('การ', 'O'),
#    ('เข้า', 'O'),
#    ('ไป', 'O'),
#    ('ตรวจสอบ', 'O'),
#    ('ของ', 'O'),
#    ('หนังสือพิมพ์', 'O'),
#    ('_', 'O'),
#    ('ไชน่า', 'B_ORG'),
#    ('_', 'I_ORG'),
#    ('ยูธ', 'I_ORG'),
#    ('_', 'I_ORG'),
#    ('เดลี่', 'I_ORG'),
#    ('_', 'I_ORG'),
#    ('ยัง', 'O'),
#    ('ชี้', 'O'),
#    ('ให้', 'O'),
#    ('เห็น', 'O'),
#    ('ว่า', 'O'),
#    ('_', 'O'),
#    ('มี', 'O'),
#    ('เขื่อน', 'B_LOC'),
#    ('อยู่', 'O'),
#    ('แห่ง', 'O'),
#    ('หนึ่ง', 'O'),
#    ('_', 'O'),
#    ('ที่', 'O'),
#    ('เพิ่ง', 'O'),
#    ('สร้าง', 'O'),
#    ('เมื่อ', 'O'),
#    ('ปี', 'O'),
#    ('_', 'O'),
#    ('2539', 'B_DTM'),
#    ('_', 'E_DTM'),
#    ('ที่', 'O'),
#    ('เขต', 'O'),
#    ('หวน', 'B_LOC'),
#    ('_', 'E_LOC'),
#    ('บน', 'O'),
#    ('ฝั่ง', 'O'),
#    ('แม่น้ำเหลือง', 'B_LOC'),
#    ('_', 'E_LOC'),
#    ('กำลัง', 'O'),
#    ('มี', 'O'),
#    ('รอย', 'O'),
#    ('แตก', 'O'),
#    ('ใน', 'O'),
#    ('ระดับ', 'O'),
#    ('ที่', 'O'),
#    ('เป็น', 'O'),
#    ('อันตราย', 'O'),
#    ('บริเวณ', 'O'),
#    ('ช่วง', 'O'),
#    ('กลาง', 'O'),
#    ('ตัว', 'O'),
#    ('เชื่อน', 'O')]},
#  {'tokens': ['ขณะ',
#    'ประชาชน',
#    'ใน',
#    'พื้นที่',
#    '_',
#    'เผย',
#    'ว่า',
#    '_',
#    'มี',
#    'เขื่อน',
#    'สร้าง',
#    'ใหม่',
#    'อย่าง',
#    'น้อย',
#    '_',
#    '5',
#    '_',
#    'แห่ง',
#    '_',
#    'ที่',
#    'อยู่',
#    'ใน',
#    'สภาพ',
#    'น่า',
#    'วิตก'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_NUM',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('ขณะ', 'O'),
#    ('ประชาชน', 'O'),
#    ('ใน', 'O'),
#    ('พื้นที่', 'O'),
#    ('_', 'O'),
#    ('เผย', 'O'),
#    ('ว่า', 'O'),
#    ('_', 'O'),
#    ('มี', 'O'),
#    ('เขื่อน', 'O'),
#    ('สร้าง', 'O'),
#    ('ใหม่', 'O'),
#    ('อย่าง', 'O'),
#    ('น้อย', 'O'),
#    ('_', 'O'),
#    ('5', 'O'),
#    ('_', 'O'),
#    ('แห่ง', 'O'),
#    ('_', 'O'),
#    ('ที่', 'O'),
#    ('อยู่', 'O'),
#    ('ใน', 'O'),
#    ('สภาพ', 'O'),
#    ('น่า', 'O'),
#    ('วิตก', 'O')]},
#  {'tokens': ['ทาง',
#    'ด้าน',
#    'เจ้าหน้าที่',
#    'สำนักงาน',
#    'น้ำ',
#    'ราย',
#    'หนึ่ง',
#    '_',
#    'ระบุ',
#    'ว่า',
#    '_',
#    'รัฐบาล',
#    'กำลัง',
#    'อยู่',
#    'ระหว่าง',
#    'ดำเนินการ',
#    'สอบสวน',
#    'เรื่อง',
#    'นี้',
#    '_',
#    'แต่',
#    'ไม่',
#    'ได้',
#    'เปิดเผย',
#    'รายละเอียด',
#    'ที่',
#    'นอกเหนือ',
#    'จาก',
#    'นี้'],
#   'label': ['O',
#    'O',
#    'O',
#    'B_ORG',
#    'E_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('ทาง', 'O'),
#    ('ด้าน', 'O'),
#    ('เจ้าหน้าที่', 'B_PER'),
#    ('สำนักงาน', 'B_ORG'),
#    ('น้ำ', 'O'),
#    ('ราย', 'O'),
#    ('หนึ่ง', 'B_NUM'),
#    ('_', 'I_NUM'),
#    ('ระบุ', 'O'),
#    ('ว่า', 'O'),
#    ('_', 'O'),
#    ('รัฐบาล', 'B_ORG'),
#    ('กำลัง', 'O'),
#    ('อยู่', 'O'),
#    ('ระหว่าง', 'O'),
#    ('ดำเนินการ', 'O'),
#    ('สอบสวน', 'O'),
#    ('เรื่อง', 'O'),
#    ('นี้', 'O'),
#    ('_', 'O'),
#    ('แต่', 'O'),
#    ('ไม่', 'O'),
#    ('ได้', 'O'),
#    ('เปิดเผย', 'O'),
#    ('รายละเอียด', 'O'),
#    ('ที่', 'O'),
#    ('นอกเหนือ', 'O'),
#    ('จาก', 'O'),
#    ('นี้', 'O')]},
#  {'tokens': ['อย่างไรก็ดี',
#    '_',
#    'สถานการณ์',
#    'ข้าง',
#    'ต้น',
#    '_',
#    'ไม่',
#    'ได้',
#    'จำกัด',
#    'อยู่',
#    'เฉพาะ',
#    'ที่',
#    'มณฑลกานซู',
#    '_',
#    'เพราะ',
#    'ยัง',
#    'มี',
#    'เขื่อน',
#    'อีก',
#    'กว่า',
#    '_',
#    '40',
#    '%',
#    '_',
#    'ใน',
#    'จีน',
#    '_',
#    'หรือ',
#    'ราว',
#    '_',
#    '37,000',
#    '_',
#    'แห่ง',
#    '_',
#    'มี',
#    'สภาพ',
#    'ร้าว',
#    '_',
#    'และ',
#    'เป็น',
#    'อันตราย'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_MEA',
#    'E_MEA',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_NUM',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('อย่างไรก็ดี', 'O'),
#    ('_', 'O'),
#    ('สถานการณ์', 'O'),
#    ('ข้าง', 'O'),
#    ('ต้น', 'O'),
#    ('_', 'O'),
#    ('ไม่', 'O'),
#    ('ได้', 'O'),
#    ('จำกัด', 'O'),
#    ('อยู่', 'O'),
#    ('เฉพาะ', 'O'),
#    ('ที่', 'O'),
#    ('มณฑลกานซู', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('เพราะ', 'O'),
#    ('ยัง', 'O'),
#    ('มี', 'O'),
#    ('เขื่อน', 'O'),
#    ('อีก', 'O'),
#    ('กว่า', 'O'),
#    ('_', 'O'),
#    ('40', 'B_PER'),
#    ('%', 'I_PER'),
#    ('_', 'I_PER'),
#    ('ใน', 'O'),
#    ('จีน', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('หรือ', 'O'),
#    ('ราว', 'O'),
#    ('_', 'O'),
#    ('37,000', 'B_NUM'),
#    ('_', 'I_NUM'),
#    ('แห่ง', 'O'),
#    ('_', 'O'),
#    ('มี', 'O'),
#    ('สภาพ', 'O'),
#    ('ร้าว', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('เป็น', 'O'),
#    ('อันตราย', 'O')]},
#  {'tokens': ['ใน',
#    'จำนวน',
#    'นี้',
#    '_',
#    'มี',
#    'อยู่',
#    'ประมาณ',
#    '_',
#    '3,640',
#    '_',
#    'แห่ง',
#    '_',
#    'ที่',
#    'อยู่',
#    'ระหว่าง',
#    'การ',
#    'เสริม',
#    'ความ',
#    'แข็งแกร่ง',
#    '_',
#    'และ',
#    'อีก',
#    '_',
#    '7,600',
#    '_',
#    'แห่ง',
#    '_',
#    'จำเป็น',
#    'ต้อง',
#    'ได้รับ',
#    'ความ',
#    'ใส่ใจ',
#    'อย่าง',
#    'เร่งด่วน'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_NUM',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_NUM',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('ใน', 'O'),
#    ('จำนวน', 'O'),
#    ('นี้', 'O'),
#    ('_', 'O'),
#    ('มี', 'O'),
#    ('อยู่', 'O'),
#    ('ประมาณ', 'O'),
#    ('_', 'O'),
#    ('3,640', 'B_NUM'),
#    ('_', 'O'),
#    ('แห่ง', 'O'),
#    ('_', 'O'),
#    ('ที่', 'O'),
#    ('อยู่', 'O'),
#    ('ระหว่าง', 'O'),
#    ('การ', 'O'),
#    ('เสริม', 'O'),
#    ('ความ', 'O'),
#    ('แข็งแกร่ง', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('อีก', 'O'),
#    ('_', 'O'),
#    ('7,600', 'B_NUM'),
#    ('_', 'O'),
#    ('แห่ง', 'O'),
#    ('_', 'O'),
#    ('จำเป็น', 'O'),
#    ('ต้อง', 'O'),
#    ('ได้รับ', 'O'),
#    ('ความ', 'O'),
#    ('ใส่ใจ', 'O'),
#    ('อย่าง', 'O'),
#    ('เร่งด่วน', 'O')]},
#  {'tokens': ['ร่าง',
#    'ของ',
#    'หลวงปู่',
#    'ทิม',
#    '_',
#    'เกจิ',
#    'ชื่อ',
#    'ดัง',
#    'แห่ง',
#    'วัดพระขาว',
#    '_',
#    'จ.',
#    'พระนครศรีอยุธยา',
#    '_',
#    'ไม่',
#    'เน่าเปื่อย',
#    '_',
#    'แม้',
#    'จะ',
#    'มรณภาพ',
#    'ไป',
#    'แล้ว',
#    '_',
#    '100',
#    '_',
#    'วัน'],
#   'label': ['O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'B_LOC',
#    'E_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_MEA',
#    'I_MEA',
#    'E_MEA'],
#   'pred': [('ร่าง', 'O'),
#    ('ของ', 'O'),
#    ('หลวงปู่', 'B_TTL'),
#    ('ทิม', 'B_PER'),
#    ('_', 'I_PER'),
#    ('เกจิ', 'B_DES'),
#    ('ชื่อ', 'B_DES'),
#    ('ดัง', 'B_DES'),
#    ('แห่ง', 'O'),
#    ('วัดพระขาว', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('จ.', 'B_LOC'),
#    ('พระนครศรีอยุธยา', 'E_LOC'),
#    ('_', 'I_LOC'),
#    ('ไม่', 'O'),
#    ('เน่าเปื่อย', 'B_DES'),
#    ('_', 'I_DES'),
#    ('แม้', 'O'),
#    ('จะ', 'O'),
#    ('มรณภาพ', 'B_DES'),
#    ('ไป', 'O'),
#    ('แล้ว', 'O'),
#    ('_', 'O'),
#    ('100', 'B_NUM'),
#    ('_', 'I_NUM'),
#    ('วัน', 'E_NUM')]},
#  {'tokens': ['ประชาชน',
#    'และ',
#    'ผู้',
#    'ที่',
#    'เลื่อมใส',
#    'ใน',
#    'องค์',
#    '_',
#    '"',
#    '_',
#    'หลวงปู่',
#    'ทิม',
#    '_',
#    '"',
#    '_',
#    'เกจิ',
#    'ชื่อ',
#    'ดัง',
#    'แห่ง',
#    'วัดพระขาว',
#    '_',
#    'จ.',
#    'พระนครศรีอยุธยา',
#    '_',
#    'ถึง',
#    'กับ',
#    'ตะลึง',
#    '_',
#    'เมื่อ',
#    'มีการ',
#    'เปิด',
#    'โลง',
#    'ศพ',
#    '_',
#    'เพื่อ',
#    'นำ',
#    'สังขาร',
#    'ของ',
#    'หลวงปู่',
#    'ทิม',
#    'ไป',
#    'บรรจุ',
#    'ไว้',
#    'ใน',
#    'โรง',
#    'แก้ว',
#    'ฝัง',
#    'มุก',
#    '_',
#    'แต่',
#    'กลับ',
#    'พบ',
#    'ว่า',
#    'สังขาร',
#    'ของ',
#    'หลวงปู่',
#    'ทิม',
#    'ไม่',
#    'เน่าเปื่อย'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'B_LOC',
#    'E_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'I_LOC',
#    'I_LOC',
#    'E_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O'],
#   'pred': [('ประชาชน', 'O'),
#    ('และ', 'O'),
#    ('ผู้', 'O'),
#    ('ที่', 'O'),
#    ('เลื่อมใส', 'O'),
#    ('ใน', 'O'),
#    ('องค์', 'B_ORG'),
#    ('_', 'I_ORG'),
#    ('"', 'O'),
#    ('_', 'O'),
#    ('หลวงปู่', 'B_PER'),
#    ('ทิม', 'I_PER'),
#    ('_', 'I_PER'),
#    ('"', 'O'),
#    ('_', 'O'),
#    ('เกจิ', 'O'),
#    ('ชื่อ', 'O'),
#    ('ดัง', 'O'),
#    ('แห่ง', 'O'),
#    ('วัดพระขาว', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('จ.', 'B_LOC'),
#    ('พระนครศรีอยุธยา', 'E_LOC'),
#    ('_', 'O'),
#    ('ถึง', 'O'),
#    ('กับ', 'O'),
#    ('ตะลึง', 'O'),
#    ('_', 'O'),
#    ('เมื่อ', 'O'),
#    ('มีการ', 'O'),
#    ('เปิด', 'O'),
#    ('โลง', 'O'),
#    ('ศพ', 'O'),
#    ('_', 'O'),
#    ('เพื่อ', 'O'),
#    ('นำ', 'O'),
#    ('สังขาร', 'O'),
#    ('ของ', 'O'),
#    ('หลวงปู่', 'B_PER'),
#    ('ทิม', 'I_PER'),
#    ('ไป', 'O'),
#    ('บรรจุ', 'O'),
#    ('ไว้', 'O'),
#    ('ใน', 'O'),
#    ('โรง', 'O'),
#    ('แก้ว', 'O'),
#    ('ฝัง', 'O'),
#    ('มุก', 'O'),
#    ('_', 'O'),
#    ('แต่', 'O'),
#    ('กลับ', 'O'),
#    ('พบ', 'O'),
#    ('ว่า', 'O'),
#    ('สังขาร', 'O'),
#    ('ของ', 'O'),
#    ('หลวงปู่', 'B_PER'),
#    ('ทิม', 'I_PER'),
#    ('ไม่', 'O'),
#    ('เน่าเปื่อย', 'O')]},
#  {'tokens': ['วัน',
#    'นี้',
#    '_',
#    '(',
#    '30',
#    '_',
#    'มิ.ย.',
#    '52',
#    ')',
#    '_',
#    'เวลา',
#    '_',
#    '08.45',
#    '_',
#    'น.',
#    '_',
#    'เจ้าหน้าที่',
#    'สำนักพระราชวัง',
#    '_',
#    'ช่วย',
#    'กัน',
#    'เคลื่อนย้าย',
#    'โรง',
#    'ศพ',
#    'ที่',
#    'บรรจุ',
#    'สังขาร',
#    'พระครู',
#    'สังวร',
#    'สมณกิจ',
#    '_',
#    'หรือ',
#    'หลวงปู่',
#    'ทิม',
#    '_',
#    'เกจิ',
#    'ชื่อ',
#    'ดัง',
#    'ของ',
#    'จังหวัด',
#    'ฯ',
#    '_',
#    'และ',
#    'อดีต',
#    'เจ้า',
#    'อาวาส',
#    'วัดพระขาว',
#    '_',
#    'อ.',
#    'บางบาล',
#    '_',
#    'จ.',
#    'พระนครศรีอยุธยา',
#    '_',
#    'ออก',
#    'มา',
#    'ที่',
#    'กลาง',
#    'ศาลา',
#    'การ',
#    'เปรียญ',
#    'ของ',
#    'วัดพระขาว',
#    '_',
#    'เพื่อ',
#    'ทำ',
#    'พิธี',
#    'เคารพ',
#    'ศพ',
#    '_',
#    'ก่อน',
#    'จะ',
#    'เคลื่อนย้าย',
#    'ร่าง',
#    'ของ',
#    'หลวงปู่',
#    'ทิม',
#    'ไป',
#    'บรรจุ',
#    'ใน',
#    'หีบ',
#    'แก้ว',
#    'ฝัง',
#    'มุก',
#    'ที่',
#    'จัดทำ',
#    'ขึ้น',
#    'ตาม',
#    '_',
#    'ความ',
#    'ประสงค์',
#    'ของ',
#    'หลวงปู่',
#    'ทิม'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'B_DTM',
#    'I_DTM',
#    'I_DTM',
#    'E_DTM',
#    'O',
#    'O',
#    'B_DTM',
#    'I_DTM',
#    'I_DTM',
#    'I_DTM',
#    'E_DTM',
#    'O',
#    'O',
#    'B_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_DES',
#    'B_PER',
#    'E_PER',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'B_LOC',
#    'E_LOC',
#    'O',
#    'B_LOC',
#    'E_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER'],
#   'pred': [('วัน', 'O'),
#    ('นี้', 'O'),
#    ('_', 'O'),
#    ('(', 'O'),
#    ('30', 'B_DTM'),
#    ('_', 'I_DTM'),
#    ('มิ.ย.', 'I_DTM'),
#    ('52', 'I_DTM'),
#    (')', 'I_DTM'),
#    ('_', 'O'),
#    ('เวลา', 'O'),
#    ('_', 'O'),
#    ('08.45', 'B_DTM'),
#    ('_', 'I_DTM'),
#    ('น.', 'I_DTM'),
#    ('_', 'O'),
#    ('เจ้าหน้าที่', 'B_ORG'),
#    ('สำนักพระราชวัง', 'I_ORG'),
#    ('_', 'O'),
#    ('ช่วย', 'O'),
#    ('กัน', 'O'),
#    ('เคลื่อนย้าย', 'O'),
#    ('โรง', 'O'),
#    ('ศพ', 'O'),
#    ('ที่', 'O'),
#    ('บรรจุ', 'O'),
#    ('สังขาร', 'O'),
#    ('พระครู', 'B_PER'),
#    ('สังวร', 'I_PER'),
#    ('สมณกิจ', 'I_PER'),
#    ('_', 'O'),
#    ('หรือ', 'O'),
#    ('หลวงปู่', 'B_PER'),
#    ('ทิม', 'E_PER'),
#    ('_', 'O'),
#    ('เกจิ', 'O'),
#    ('ชื่อ', 'O'),
#    ('ดัง', 'O'),
#    ('ของ', 'O'),
#    ('จังหวัด', 'O'),
#    ('ฯ', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('อดีต', 'O'),
#    ('เจ้า', 'O'),
#    ('อาวาส', 'O'),
#    ('วัดพระขาว', 'B_LOC'),
#    ('_', 'O'),
#    ('อ.', 'B_LOC'),
#    ('บางบาล', 'I_LOC'),
#    ('_', 'O'),
#    ('จ.', 'B_LOC'),
#    ('พระนครศรีอยุธยา', 'I_LOC'),
#    ('_', 'O'),
#    ('ออก', 'O'),
#    ('มา', 'O'),
#    ('ที่', 'O'),
#    ('กลาง', 'O'),
#    ('ศาลา', 'O'),
#    ('การ', 'O'),
#    ('เปรียญ', 'O'),
#    ('ของ', 'O'),
#    ('วัดพระขาว', 'B_LOC'),
#    ('_', 'O'),
#    ('เพื่อ', 'O'),
#    ('ทำ', 'O'),
#    ('พิธี', 'O'),
#    ('เคารพ', 'O'),
#    ('ศพ', 'O'),
#    ('_', 'O'),
#    ('ก่อน', 'O'),
#    ('จะ', 'O'),
#    ('เคลื่อนย้าย', 'O'),
#    ('ร่าง', 'O'),
#    ('ของ', 'O'),
#    ('หลวงปู่', 'B_PER'),
#    ('ทิม', 'E_PER'),
#    ('ไป', 'O'),
#    ('บรรจุ', 'O'),
#    ('ใน', 'O'),
#    ('หีบ', 'O'),
#    ('แก้ว', 'O'),
#    ('ฝัง', 'O'),
#    ('มุก', 'O'),
#    ('ที่', 'O'),
#    ('จัดทำ', 'O'),
#    ('ขึ้น', 'O'),
#    ('ตาม', 'O'),
#    ('_', 'O'),
#    ('ความ', 'O'),
#    ('ประสงค์', 'O'),
#    ('ของ', 'O'),
#    ('หลวงปู่', 'B_PER'),
#    ('ทิม', 'E_PER')]},
#  {'tokens': ['ที่',
#    'สั่ง',
#    'ลูกศิษย์',
#    'ไว้',
#    'ก่อน',
#    'มรณภาพ',
#    '_',
#    'โดย',
#    'ทันที',
#    'ที่',
#    'เปิด',
#    'โลง',
#    'ศพ',
#    'ออก',
#    'มา',
#    '_',
#    'พบ',
#    'ว่า',
#    'สังขาร',
#    'ของ',
#    'หลวงปู่',
#    'ทิม',
#    'ไม่',
#    'เน่าเปื่อย',
#    '_',
#    'และ',
#    'ยังคง',
#    'อยู่',
#    'ใน',
#    'สภาพ',
#    'เกือบ',
#    'สมบูรณ์',
#    'ทั้งหมด',
#    '_',
#    'แม้',
#    'เวลา',
#    'จะ',
#    'ผ่าน',
#    'มา',
#    'แล้ว',
#    '_',
#    '100',
#    '_',
#    'วัน'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_MEA',
#    'I_MEA',
#    'E_MEA'],
#   'pred': [('ที่', 'O'),
#    ('สั่ง', 'O'),
#    ('ลูกศิษย์', 'O'),
#    ('ไว้', 'O'),
#    ('ก่อน', 'O'),
#    ('มรณภาพ', 'O'),
#    ('_', 'O'),
#    ('โดย', 'O'),
#    ('ทันที', 'O'),
#    ('ที่', 'O'),
#    ('เปิด', 'O'),
#    ('โลง', 'O'),
#    ('ศพ', 'O'),
#    ('ออก', 'O'),
#    ('มา', 'O'),
#    ('_', 'O'),
#    ('พบ', 'O'),
#    ('ว่า', 'O'),
#    ('สังขาร', 'O'),
#    ('ของ', 'B_PER'),
#    ('หลวงปู่', 'B_TTL'),
#    ('ทิม', 'B_PER'),
#    ('ไม่', 'O'),
#    ('เน่าเปื่อย', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('ยังคง', 'O'),
#    ('อยู่', 'O'),
#    ('ใน', 'O'),
#    ('สภาพ', 'O'),
#    ('เกือบ', 'O'),
#    ('สมบูรณ์', 'O'),
#    ('ทั้งหมด', 'O'),
#    ('_', 'O'),
#    ('แม้', 'O'),
#    ('เวลา', 'O'),
#    ('จะ', 'O'),
#    ('ผ่าน', 'O'),
#    ('มา', 'O'),
#    ('แล้ว', 'O'),
#    ('_', 'O'),
#    ('100', 'B_NUM'),
#    ('_', 'O'),
#    ('วัน', 'B_NUM')]},
#  {'tokens': ['นอกจาก',
#    'นี้',
#    'ยัง',
#    'พบ',
#    'ว่า',
#    '_',
#    'สภาพ',
#    'ศพ',
#    'ของ',
#    'หลวงปู่',
#    'ทิม',
#    '_',
#    'โดยเฉพาะ',
#    'ที่',
#    'เนื้อตัว',
#    'นั้น',
#    'ยัง',
#    'อ่อนนุ่ม',
#    '_',
#    'มี',
#    'สี',
#    'เหลือง',
#    'อ่อน',
#    'ๆ',
#    '_',
#    'คล้าย',
#    'กับ',
#    'คน',
#    'นอน',
#    'หลับ',
#    '_',
#    'และ',
#    'ยัง',
#    'พบ',
#    'อีก',
#    'ว่า',
#    'ใน',
#    'ช่วง',
#    'ที่',
#    'มีการ',
#    'เปิด',
#    'โลง',
#    'ศพ',
#    '_',
#    'มี',
#    'กลิ่น',
#    'หอม',
#    'ว่านไพร',
#    '_',
#    'และ',
#    'กลิ่น',
#    'ชาน',
#    'หมาก',
#    'หอม',
#    'ฟุ้ง',
#    'ไป',
#    'ทั่ว',
#    'ศาลา',
#    '_',
#    'สร้าง',
#    'ความ',
#    'อัศจรรย์',
#    'ให้',
#    'กับ',
#    'ลูกศิษย์',
#    '_',
#    'กว่า',
#    '_',
#    '500',
#    '_',
#    'คน',
#    '_',
#    'ที่',
#    'มา',
#    'ร่วม',
#    'ใน',
#    'ครั้ง',
#    'นี้'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_MEA',
#    'O',
#    'B_MEA',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('นอกจาก', 'O'),
#    ('นี้', 'O'),
#    ('ยัง', 'O'),
#    ('พบ', 'O'),
#    ('ว่า', 'O'),
#    ('_', 'O'),
#    ('สภาพ', 'O'),
#    ('ศพ', 'O'),
#    ('ของ', 'O'),
#    ('หลวงปู่', 'B_PER'),
#    ('ทิม', 'I_PER'),
#    ('_', 'I_PER'),
#    ('โดยเฉพาะ', 'O'),
#    ('ที่', 'O'),
#    ('เนื้อตัว', 'O'),
#    ('นั้น', 'O'),
#    ('ยัง', 'O'),
#    ('อ่อนนุ่ม', 'O'),
#    ('_', 'O'),
#    ('มี', 'O'),
#    ('สี', 'O'),
#    ('เหลือง', 'O'),
#    ('อ่อน', 'O'),
#    ('ๆ', 'O'),
#    ('_', 'O'),
#    ('คล้าย', 'O'),
#    ('กับ', 'O'),
#    ('คน', 'O'),
#    ('นอน', 'O'),
#    ('หลับ', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('ยัง', 'O'),
#    ('พบ', 'O'),
#    ('อีก', 'O'),
#    ('ว่า', 'O'),
#    ('ใน', 'O'),
#    ('ช่วง', 'O'),
#    ('ที่', 'O'),
#    ('มี', 'O'),
#    ('การ', 'O'),
#    ('เปิด', 'O'),
#    ('โลง', 'O'),
#    ('ศพ', 'O'),
#    ('_', 'O'),
#    ('มี', 'O'),
#    ('กลิ่น', 'O'),
#    ('หอม', 'O'),
#    ('ว่านไพร', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('กลิ่น', 'O'),
#    ('ชาน', 'O'),
#    ('หมาก', 'O'),
#    ('หอม', 'O'),
#    ('ฟุ้ง', 'O'),
#    ('ไป', 'O'),
#    ('ทั่ว', 'O'),
#    ('ศาลา', 'O'),
#    ('_', 'O'),
#    ('สร้าง', 'O'),
#    ('ความ', 'O'),
#    ('อัศจรรย์', 'O'),
#    ('ให้', 'O'),
#    ('กับ', 'O'),
#    ('ลูกศิษย์', 'O'),
#    ('_', 'O'),
#    ('กว่า', 'O'),
#    ('_', 'O'),
#    ('500', 'B_NUM'),
#    ('_', 'I_NUM'),
#    ('คน', 'I_NUM'),
#    ('_', 'I_NUM'),
#    ('ที่', 'O'),
#    ('มา', 'O'),
#    ('ร่วม', 'O'),
#    ('ใน', 'O'),
#    ('ครั้ง', 'O'),
#    ('นี้', 'O')]},
#  {'tokens': ['หลวงปู่',
#    'ทิม',
#    '_',
#    'เกจิ',
#    'ชื่อ',
#    'ดัง',
#    '_',
#    'จ.',
#    'พระนครศรีอยุธยา',
#    '_',
#    'และ',
#    'เป็น',
#    'อดีต',
#    'เจ้า',
#    'อาวาส',
#    'วัดพระขาว',
#    '_',
#    'อ.',
#    'บางบาล',
#    '_',
#    'มรณภาพ',
#    'เมื่อ',
#    'วันที่',
#    '_',
#    '22',
#    '_',
#    'มีนาคม',
#    '_',
#    '2552',
#    '_',
#    'ที่',
#    'โรงพยาบาล',
#    'โรคทรวงอก',
#    '_',
#    'จ.',
#    'นนทบุรี',
#    '_',
#    'จาก',
#    'นั้น',
#    'ได้',
#    'เคลื่อนย้าย',
#    'ศพ',
#    'มา',
#    'ตั้ง',
#    'สวด',
#    'บำเพ็ญ',
#    'กุศล',
#    'ที่',
#    'วัด',
#    'พระขาว',
#    '_',
#    'อ.',
#    'บางบาล',
#    '_',
#    'จน',
#    'ครบ',
#    '_',
#    '100',
#    '_',
#    'วัน',
#    'เมื่อ',
#    'คืน',
#    'นี้'],
#   'label': ['B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'E_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'B_LOC',
#    'E_LOC',
#    'O',
#    'O',
#    'O',
#    'B_DTM',
#    'I_DTM',
#    'I_DTM',
#    'I_DTM',
#    'I_DTM',
#    'I_DTM',
#    'E_DTM',
#    'O',
#    'O',
#    'B_LOC',
#    'E_LOC',
#    'O',
#    'B_LOC',
#    'E_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'E_LOC',
#    'O',
#    'B_LOC',
#    'E_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_MEA',
#    'I_MEA',
#    'E_MEA',
#    'O',
#    'O',
#    'O'],
#   'pred': [('หลวงปู่', 'B_PER'),
#    ('ทิม', 'I_PER'),
#    ('_', 'I_PER'),
#    ('เกจิ', 'O'),
#    ('ชื่อ', 'O'),
#    ('ดัง', 'O'),
#    ('_', 'O'),
#    ('จ.', 'B_LOC'),
#    ('พระนครศรีอยุธยา', 'I_LOC'),
#    ('_', 'I_LOC'),
#    ('และ', 'O'),
#    ('เป็น', 'O'),
#    ('อดีต', 'O'),
#    ('เจ้า', 'O'),
#    ('อาวาส', 'O'),
#    ('วัดพระขาว', 'B_LOC'),
#    ('_', 'I_LOC'),
#    ('อ.', 'B_LOC'),
#    ('บางบาล', 'I_LOC'),
#    ('_', 'I_LOC'),
#    ('มรณภาพ', 'O'),
#    ('เมื่อ', 'O'),
#    ('วันที่', 'B_DTM'),
#    ('_', 'I_DTM'),
#    ('22', 'I_DTM'),
#    ('_', 'I_DTM'),
#    ('มีนาคม', 'I_DTM'),
#    ('_', 'I_DTM'),
#    ('2552', 'I_DTM'),
#    ('_', 'I_DTM'),
#    ('ที่', 'O'),
#    ('โรงพยาบาล', 'B_LOC'),
#    ('โรคทรวงอก', 'B_DES'),
#    ('_', 'I_LOC'),
#    ('จ.', 'B_LOC'),
#    ('นนทบุรี', 'I_LOC'),
#    ('_', 'I_LOC'),
#    ('จาก', 'O'),
#    ('นั้น', 'O'),
#    ('ได้', 'O'),
#    ('เคลื่อนย้าย', 'O'),
#    ('ศพ', 'O'),
#    ('มา', 'O'),
#    ('ตั้ง', 'O'),
#    ('สวด', 'O'),
#    ('บำเพ็ญ', 'O'),
#    ('กุศล', 'O'),
#    ('ที่', 'O'),
#    ('วัด', 'B_LOC'),
#    ('พระขาว', 'I_LOC'),
#    ('_', 'I_LOC'),
#    ('อ.', 'B_LOC'),
#    ('บางบาล', 'I_LOC'),
#    ('_', 'I_LOC'),
#    ('จน', 'O'),
#    ('ครบ', 'O'),
#    ('_', 'O'),
#    ('100', 'B_NUM'),
#    ('_', 'I_NUM'),
#    ('วัน', 'I_NUM'),
#    ('เมื่อ', 'O'),
#    ('คืน', 'O'),
#    ('นี้', 'O')]},
#  {'tokens': ['จึง',
#    'ได้',
#    'มีการ',
#    'เปิด',
#    'โลง',
#    'ศพ',
#    '_',
#    'เพื่อ',
#    'เคลื่อนย้าย',
#    'ร่าง',
#    'ของ',
#    'หลวงปู่',
#    'ทิม',
#    'ไป',
#    'บรรจุ',
#    'ยัง',
#    'หีบ',
#    'แก้ว',
#    'ฝัง',
#    'มุก',
#    '_',
#    'ตาม',
#    'ความ',
#    'ประสงค์',
#    'ของ',
#    'หลวงปู่',
#    'ทิม',
#    '_',
#    'เพื่อ',
#    'ให้',
#    'ประชาชน',
#    'ได้',
#    'กราบไหว้',
#    '_',
#    'และ',
#    'ใน',
#    'วัน',
#    'อาทิตย์',
#    'ที่',
#    '_',
#    '5',
#    '_',
#    'กรกฎาคม',
#    'นี้'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_DTM',
#    'I_DTM',
#    'I_DTM',
#    'I_DTM',
#    'I_DTM',
#    'I_DTM',
#    'E_DTM',
#    'O'],
#   'pred': [('จึง', 'O'),
#    ('ได้', 'O'),
#    ('มีการ', 'O'),
#    ('เปิด', 'O'),
#    ('โลง', 'O'),
#    ('ศพ', 'O'),
#    ('_', 'O'),
#    ('เพื่อ', 'O'),
#    ('เคลื่อนย้าย', 'O'),
#    ('ร่าง', 'O'),
#    ('ของ', 'O'),
#    ('หลวงปู่', 'B_PER'),
#    ('ทิม', 'E_PER'),
#    ('ไป', 'O'),
#    ('บรรจุ', 'O'),
#    ('ยัง', 'O'),
#    ('หีบ', 'O'),
#    ('แก้ว', 'O'),
#    ('ฝัง', 'O'),
#    ('มุก', 'O'),
#    ('_', 'O'),
#    ('ตาม', 'O'),
#    ('ความ', 'O'),
#    ('ประสงค์', 'O'),
#    ('ของ', 'O'),
#    ('หลวงปู่', 'B_PER'),
#    ('ทิม', 'E_PER'),
#    ('_', 'O'),
#    ('เพื่อ', 'O'),
#    ('ให้', 'O'),
#    ('ประชาชน', 'O'),
#    ('ได้', 'O'),
#    ('กราบไหว้', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('ใน', 'O'),
#    ('วัน', 'O'),
#    ('อาทิตย์', 'O'),
#    ('ที่', 'O'),
#    ('_', 'O'),
#    ('5', 'B_NUM'),
#    ('_', 'O'),
#    ('กรกฎาคม', 'B_DTM'),
#    ('นี้', 'O')]},
#  {'tokens': ['วัดพระขาว',
#    'จะ',
#    'จัด',
#    'พิธี',
#    'เชิญ',
#    'หีบ',
#    'แก้ว',
#    'ฝัง',
#    'มุก',
#    '_',
#    'ที่',
#    'บรรจุ',
#    'สังขาร',
#    'ของ',
#    'หลวงปู่',
#    'ทิม',
#    '_',
#    'ขึ้น',
#    'สู่',
#    'มณฑป',
#    'ลาย',
#    'รดน้ำ',
#    '_',
#    'ที่',
#    'มี',
#    'ชื่อ',
#    'ว่า',
#    '_',
#    'อัตตสันตมหาเถราจารย์',
#    '_',
#    'ซึ่ง',
#    'เป็น',
#    'สิ่ง',
#    'ปลูกสร้าง',
#    'ที่',
#    'หลวงปู่',
#    'ทิม',
#    'ให้',
#    'จัดสร้าง',
#    'ไว้',
#    '_',
#    'และ',
#    'หาก',
#    'หลวงปู่',
#    'ทิม',
#    'มรณภาพ',
#    'ลง',
#    'ให้',
#    'นำ',
#    'ร่าง',
#    'ของ',
#    'หลวงปู่',
#    'ทิม',
#    '_',
#    'ไป',
#    'ตั้ง',
#    'ไว้',
#    'ยัง',
#    'ที่',
#    'ดังกล่าว'],
#   'label': ['B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('วัดพระขาว', 'B_LOC'),
#    ('จะ', 'O'),
#    ('จัด', 'O'),
#    ('พิธี', 'O'),
#    ('เชิญ', 'O'),
#    ('หีบ', 'O'),
#    ('แก้ว', 'O'),
#    ('ฝัง', 'O'),
#    ('มุก', 'O'),
#    ('_', 'I_LOC'),
#    ('ที่', 'O'),
#    ('บรรจุ', 'O'),
#    ('สังขาร', 'O'),
#    ('ของ', 'O'),
#    ('หลวงปู่', 'B_PER'),
#    ('ทิม', 'I_PER'),
#    ('_', 'I_PER'),
#    ('ขึ้น', 'O'),
#    ('สู่', 'O'),
#    ('มณฑป', 'O'),
#    ('ลาย', 'O'),
#    ('รดน้ำ', 'O'),
#    ('_', 'I_LOC'),
#    ('ที่', 'O'),
#    ('มี', 'O'),
#    ('ชื่อ', 'O'),
#    ('ว่า', 'O'),
#    ('_', 'I_LOC'),
#    ('อัตตสันตมหาเถราจารย์', 'B_PER'),
#    ('_', 'I_PER'),
#    ('ซึ่ง', 'O'),
#    ('เป็น', 'O'),
#    ('สิ่ง', 'O'),
#    ('ปลูกสร้าง', 'O'),
#    ('ที่', 'O'),
#    ('หลวงปู่', 'B_PER'),
#    ('ทิม', 'I_PER'),
#    ('ให้', 'O'),
#    ('จัดสร้าง', 'O'),
#    ('ไว้', 'O'),
#    ('_', 'I_PER'),
#    ('และ', 'O'),
#    ('หาก', 'O'),
#    ('หลวงปู่', 'B_PER'),
#    ('ทิม', 'I_PER'),
#    ('มรณภาพ', 'O'),
#    ('ลง', 'O'),
#    ('ให้', 'O'),
#    ('นำ', 'O'),
#    ('ร่าง', 'O'),
#    ('ของ', 'O'),
#    ('หลวงปู่', 'B_PER'),
#    ('ทิม', 'I_PER'),
#    ('_', 'I_PER'),
#    ('ไป', 'O'),
#    ('ตั้ง', 'O'),
#    ('ไว้', 'O'),
#    ('ยัง', 'O'),
#    ('ที่', 'O'),
#    ('ดังกล่าว', 'O')]},
#  {'tokens': ['ก.เกษตรฯ',
#    '_',
#    'เตรียม',
#    'จัด',
#    'งาน',
#    'ประกวด',
#    'โครงการ',
#    'ส่งเสริม',
#    'เอกลักษณ์',
#    'คุณค่า',
#    'ผ้า',
#    'ไหม',
#    'ไทย',
#    '_',
#    'ชิง',
#    'ถ้วย',
#    'รางวัล',
#    'พระราชทาน'],
#   'label': ['B_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('ก.', 'B_LOC'),
#    ('เกษตรฯ', 'E_LOC'),
#    ('_', 'O'),
#    ('เตรียม', 'O'),
#    ('จัด', 'O'),
#    ('งาน', 'O'),
#    ('ประกวด', 'O'),
#    ('โครงการ', 'O'),
#    ('ส่งเสริม', 'O'),
#    ('เอกลักษณ์', 'O'),
#    ('คุณค่า', 'O'),
#    ('ผ้า', 'O'),
#    ('ไหม', 'O'),
#    ('ไทย', 'O'),
#    ('_', 'O'),
#    ('ชิง', 'O'),
#    ('ถ้วย', 'O'),
#    ('รางวัล', 'O'),
#    ('พระราชทาน', 'O')]},
#  {'tokens': ['กระทรวง',
#    'เกษตร',
#    'และ',
#    'สหกรณ์',
#    '_',
#    'เตรียม',
#    'จัด',
#    'งาน',
#    'ประกวด',
#    'โครงการ',
#    'ส่งเสริม',
#    'เอกลักษณ์',
#    'คุณค่า',
#    'ผ้า',
#    'ไหม',
#    'ไทย',
#    '_',
#    'ชิง',
#    'ถ้วย',
#    'รางวัล',
#    'พระราชทาน',
#    'สมเด็จพระนางเจ้า',
#    'สิริกิติ์',
#    '_',
#    'พระบรมราชินีนาถ',
#    '_',
#    'หวัง',
#    'สืบสาน',
#    'เอกลักษณ์',
#    'ไทย',
#    '_',
#    'เผยแพร่',
#    'ประชาสัมพันธ์',
#    'ตรา',
#    'นกยูง',
#    'พระราชทาน',
#    '_',
#    'เครื่องหมาย',
#    'รับรอง',
#    'คุณภาพ',
#    'ไหม',
#    'ไทย'],
#   'label': ['B_ORG',
#    'I_ORG',
#    'I_ORG',
#    'E_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_DES',
#    'B_PER',
#    'O',
#    'B_DES',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC'],
#   'pred': [('กระทรวง', 'B_ORG'),
#    ('เกษตร', 'I_ORG'),
#    ('และ', 'O'),
#    ('สหกรณ์', 'I_ORG'),
#    ('_', 'O'),
#    ('เตรียม', 'O'),
#    ('จัด', 'O'),
#    ('งาน', 'O'),
#    ('ประกวด', 'O'),
#    ('โครงการ', 'O'),
#    ('ส่งเสริม', 'O'),
#    ('เอกลักษณ์', 'O'),
#    ('คุณค่า', 'O'),
#    ('ผ้า', 'O'),
#    ('ไหม', 'O'),
#    ('ไทย', 'O'),
#    ('_', 'O'),
#    ('ชิง', 'O'),
#    ('ถ้วย', 'O'),
#    ('รางวัล', 'O'),
#    ('พระราชทาน', 'O'),
#    ('สมเด็จพระนางเจ้า', 'B_PER'),
#    ('สิริกิติ์', 'I_PER'),
#    ('_', 'O'),
#    ('พระบรมราชินีนาถ', 'E_PER'),
#    ('_', 'O'),
#    ('หวัง', 'O'),
#    ('สืบสาน', 'O'),
#    ('เอกลักษณ์', 'O'),
#    ('ไทย', 'O'),
#    ('_', 'O'),
#    ('เผยแพร่', 'O'),
#    ('ประชาสัมพันธ์', 'O'),
#    ('ตรา', 'O'),
#    ('นกยูง', 'O'),
#    ('พระราชทาน', 'O'),
#    ('_', 'O'),
#    ('เครื่องหมาย', 'O'),
#    ('รับรอง', 'O'),
#    ('คุณภาพ', 'O'),
#    ('ไหม', 'O'),
#    ('ไทย', 'O')]},
#  {'tokens': ['นาย',
#    'จรัลธาดา',
#    '_',
#    'กรรณสูต',
#    '_',
#    'ปลัด',
#    'กระทรวง',
#    'เกษตร',
#    'และ',
#    'สหกรณ์',
#    '_',
#    'เปิดเผย',
#    'ภายหลัง',
#    'เป็น',
#    'ประธาน',
#    'แถลง',
#    'ข่าว',
#    '_',
#    '"',
#    'โครงการ',
#    'ส่งเสริม',
#    'เอกลักษณ์',
#    'คุณค่า',
#    'ผ้า',
#    'ไหม',
#    'ไทย',
#    '"',
#    '_',
#    'ณ',
#    '_',
#    'ลาน',
#    'กิจกรรม',
#    '_',
#    'ชั้น',
#    '_',
#    '1',
#    '_',
#    'จามจุรีสแควร์',
#    'ว่า',
#    '_',
#    'กระทรวง',
#    'เกษตร',
#    'และ',
#    'สหกรณ์'],
#   'label': ['B_TTL',
#    'B_PER',
#    'I_PER',
#    'E_PER',
#    'O',
#    'O',
#    'B_ORG',
#    'I_ORG',
#    'I_ORG',
#    'E_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_MEA',
#    'O',
#    'B_MEA',
#    'O',
#    'O',
#    'B_ORG',
#    'I_ORG',
#    'I_ORG',
#    'E_ORG'],
#   'pred': [('นาย', 'B_TTL'),
#    ('จรัลธาดา', 'B_PER'),
#    ('_', 'I_PER'),
#    ('กรรณสูต', 'E_PER'),
#    ('_', 'B_TTL'),
#    ('ปลัด', 'B_TTL'),
#    ('กระทรวง', 'B_ORG'),
#    ('เกษตร', 'I_ORG'),
#    ('และ', 'O'),
#    ('สหกรณ์', 'I_ORG'),
#    ('_', 'O'),
#    ('เปิดเผย', 'O'),
#    ('ภายหลัง', 'O'),
#    ('เป็น', 'O'),
#    ('ประธาน', 'O'),
#    ('แถลง', 'O'),
#    ('ข่าว', 'O'),
#    ('_', 'O'),
#    ('"', 'O'),
#    ('โครงการ', 'O'),
#    ('ส่งเสริม', 'O'),
#    ('เอกลักษณ์', 'O'),
#    ('คุณค่า', 'O'),
#    ('ผ้า', 'O'),
#    ('ไหม', 'O'),
#    ('ไทย', 'O'),
#    ('"', 'O'),
#    ('_', 'O'),
#    ('ณ', 'O'),
#    ('_', 'O'),
#    ('ลาน', 'O'),
#    ('กิจกรรม', 'O'),
#    ('_', 'O'),
#    ('ชั้น', 'O'),
#    ('_', 'O'),
#    ('1', 'O'),
#    ('_', 'O'),
#    ('จามจุรีสแควร์', 'O'),
#    ('ว่า', 'O'),
#    ('_', 'O'),
#    ('กระทรวง', 'B_ORG'),
#    ('เกษตร', 'I_ORG'),
#    ('และ', 'O'),
#    ('สหกรณ์', 'I_ORG')]},
#  {'tokens': ['โดย',
#    '_',
#    'สถาบัน',
#    'หม่อน',
#    'ไหมแห่งชาติ',
#    'เฉลิม',
#    'พระเกียรติ',
#    '_',
#    'สมเด็จพระนางเจ้า',
#    'สิริกิติ์',
#    '_',
#    'พระบรมราชินีนาถ',
#    '_',
#    'จัด',
#    'โครงการ',
#    'ส่งเสริม',
#    'เอกลักษณ์',
#    'คุณค่า',
#    'ผ้า',
#    'ไหม',
#    'ไทย',
#    'ขึ้น',
#    '_',
#    'ระหว่าง',
#    'วันที่',
#    '_',
#    '6',
#    '-',
#    '10',
#    '_',
#    'สิงหาคม',
#    '_',
# ...
#  {'tokens': ['"',
#    'แถลง',
#    'การณ์',
#    'ร่วม',
#    'ลด',
#    'อาวุธ',
#    'นิวเคลียร์',
#    'ครั้ง',
#    'นี้',
#    '_',
#    'เป็น',
#    'การ',
#    'ทำ',
#    'ข้อ',
#    'ตกลง',
#    'ร่วม',
#    'กัน',
#    'อย่าง',
#    'แท้จริง',
#    'และ',
#    'เหมาะสม',
#    'กับ',
#    'ทั้ง',
#    'สอง',
#    'ฝ่าย',
#    '_',
#    'และ',
#    'ยัง',
#    'สะท้อน',
#    'ว่า',
#    'ชาว',
#    'อเมริกัน',
#    'ตัดสินใจ',
#    'ที่',
#    'จะ',
#    'ยอมรับ',
#    'รัสเซีย'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_MEA',
#    'E_MEA',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('"', 'O'),
#    ('แถลง', 'B_TTL'),
#    ('การณ์', 'I_TTL'),
#    ('ร่วม', 'O'),
#    ('ลด', 'O'),
#    ('อาวุธ', 'O'),
#    ('นิวเคลียร์', 'O'),
#    ('ครั้ง', 'O'),
#    ('นี้', 'O'),
#    ('_', 'O'),
#    ('เป็น', 'O'),
#    ('การ', 'O'),
#    ('ทำ', 'O'),
#    ('ข้อ', 'O'),
#    ('ตกลง', 'O'),
#    ('ร่วม', 'O'),
#    ('กัน', 'O'),
#    ('อย่าง', 'O'),
#    ('แท้จริง', 'O'),
#    ('และ', 'O'),
#    ('เหมาะสม', 'O'),
#    ('กับ', 'O'),
#    ('ทั้ง', 'O'),
#    ('สอง', 'O'),
#    ('ฝ่าย', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('ยัง', 'O'),
#    ('สะท้อน', 'O'),
#    ('ว่า', 'O'),
#    ('ชาว', 'O'),
#    ('อเมริกัน', 'B_LOC'),
#    ('ตัดสินใจ', 'O'),
#    ('ที่', 'O'),
#    ('จะ', 'O'),
#    ('ยอมรับ', 'O'),
#    ('รัสเซีย', 'B_LOC')]},
#  {'tokens': ['ประธานาธิบดี',
#    'โอบามา',
#    'ไม่',
#    'ได้',
#    'ติดใจ',
#    'ช่วง',
#    'สงคราม',
#    'เย็น',
#    'กับ',
#    'รัสเซีย',
#    'อีก',
#    '_',
#    'และ',
#    'ไม่',
#    'ได้',
#    'มอง',
#    'ว่า',
#    'รัสเซีย',
#    'เป็น',
#    'ศัตรู',
#    'ของ',
#    'สหรัฐ',
#    'อีก',
#    'แล้ว',
#    '"',
#    '_',
#    'นาย',
#    'อเลกซี',
#    '_',
#    'มาลาชเชนโก',
#    '_',
#    'นัก',
#    'วิเคราะห์',
#    'จาก',
#    'ศูนย์คาร์เนกี',
#    '_',
#    'ใน',
#    'กรุงมอสโก',
#    '_',
#    'ให้',
#    'ความเห็น'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'I_PER',
#    'E_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_ORG',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O'],
#   'pred': [('ประธานาธิบดี', 'O'),
#    ('โอบามา', 'B_PER'),
#    ('ไม่', 'O'),
#    ('ได้', 'O'),
#    ('ติดใจ', 'O'),
#    ('ช่วง', 'O'),
#    ('สงคราม', 'O'),
#    ('เย็น', 'O'),
#    ('กับ', 'O'),
#    ('รัสเซีย', 'B_LOC'),
#    ('อีก', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('ไม่', 'O'),
#    ('ได้', 'O'),
#    ('มอง', 'O'),
#    ('ว่า', 'O'),
#    ('รัสเซีย', 'B_LOC'),
#    ('เป็น', 'O'),
#    ('ศัตรู', 'O'),
#    ('ของ', 'O'),
#    ('สหรัฐ', 'B_LOC'),
#    ('อีก', 'O'),
#    ('แล้ว', 'O'),
#    ('"', 'O'),
#    ('_', 'O'),
#    ('นาย', 'B_TTL'),
#    ('อเลกซี', 'B_PER'),
#    ('_', 'I_PER'),
#    ('มาลาชเชนโก', 'E_PER'),
#    ('_', 'O'),
#    ('นัก', 'B_DES'),
#    ('วิเคราะห์', 'B_DES'),
#    ('จาก', 'O'),
#    ('ศูนย์คาร์เนกี', 'B_ORG'),
#    ('_', 'O'),
#    ('ใน', 'O'),
#    ('กรุงมอสโก', 'B_LOC'),
#    ('_', 'O'),
#    ('ให้', 'O'),
#    ('ความเห็น', 'O')]},
#  {'tokens': ['นอกจาก',
#    'นี้',
#    '_',
#    'นาย',
#    'โอบามา',
#    '_',
#    'ยัง',
#    'เสนอ',
#    'ให้',
#    'สหรัฐ',
#    'เป็น',
#    'เจ้าภาพ',
#    'การ',
#    'ประชุม',
#    'สุด',
#    'ยอด',
#    'ว่า',
#    'ด้วย',
#    'ความ',
#    'มั่นคง',
#    'ด้าน',
#    'นิวเคลียร์',
#    'โลก',
#    'ใน',
#    'ปี',
#    'หน้า'],
#   'label': ['O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O'],
#   'pred': [('นอกจาก', 'O'),
#    ('นี้', 'O'),
#    ('_', 'O'),
#    ('นาย', 'B_PER'),
#    ('โอบามา', 'E_PER'),
#    ('_', 'O'),
#    ('ยัง', 'O'),
#    ('เสนอ', 'O'),
#    ('ให้', 'O'),
#    ('สหรัฐ', 'B_LOC'),
#    ('เป็น', 'O'),
#    ('เจ้าภาพ', 'O'),
#    ('การ', 'O'),
#    ('ประชุม', 'O'),
#    ('สุด', 'O'),
#    ('ยอด', 'O'),
#    ('ว่า', 'O'),
#    ('ด้วย', 'O'),
#    ('ความ', 'O'),
#    ('มั่นคง', 'O'),
#    ('ด้าน', 'O'),
#    ('นิวเคลียร์', 'O'),
#    ('โลก', 'O'),
#    ('ใน', 'O'),
#    ('ปี', 'O'),
#    ('หน้า', 'O')]},
#  {'tokens': ['พร้อม',
#    'ทั้ง',
#    'เสนอแนะ',
#    'แก่',
#    'นาย',
#    'เมดเวเดฟ',
#    'ว่า',
#    'รัสเซีย',
#    'ควร',
#    'เป็น',
#    'เจ้าภาพ',
#    'การ',
#    'ประชุม',
#    'สุด',
#    'ยอด',
#    'นี้',
#    'ใน',
#    'ปี',
#    'ถัด',
#    'มา',
#    '_',
#    'เพื่อ',
#    'ร่าง',
#    'สนธิสัญญา',
#    'ห้าม',
#    'แพร่กระจาย',
#    'อาวุธ',
#    'นิวเคลียร์',
#    'ฉบับ',
#    'ใหม่',
#    'ที่',
#    'มี',
#    'เนื้อหา',
#    'เข้มข้น',
#    'กว่า',
#    'เดิม'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'O',
#    'B_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('พร้อม', 'O'),
#    ('ทั้ง', 'O'),
#    ('เสนอแนะ', 'O'),
#    ('แก่', 'O'),
#    ('นาย', 'B_TTL'),
#    ('เมดเวเดฟ', 'B_PER'),
#    ('ว่า', 'O'),
#    ('รัสเซีย', 'B_LOC'),
#    ('ควร', 'O'),
#    ('เป็น', 'O'),
#    ('เจ้าภาพ', 'O'),
#    ('การ', 'O'),
#    ('ประชุม', 'O'),
#    ('สุด', 'O'),
#    ('ยอด', 'O'),
#    ('นี้', 'O'),
#    ('ใน', 'O'),
#    ('ปี', 'O'),
#    ('ถัด', 'O'),
#    ('มา', 'O'),
#    ('_', 'O'),
#    ('เพื่อ', 'O'),
#    ('ร่าง', 'O'),
#    ('สนธิสัญญา', 'O'),
#    ('ห้าม', 'O'),
#    ('แพร่กระจาย', 'O'),
#    ('อาวุธ', 'O'),
#    ('นิวเคลียร์', 'O'),
#    ('ฉบับ', 'O'),
#    ('ใหม่', 'O'),
#    ('ที่', 'O'),
#    ('มี', 'O'),
#    ('เนื้อหา', 'O'),
#    ('เข้มข้น', 'O'),
#    ('กว่า', 'O'),
#    ('เดิม', 'O')]},
#  {'tokens': ['ข่าว',
#    'ย่อย',
#    '_',
#    ':',
#    '_',
#    'กัมพูชา',
#    'ฉลอง',
#    '_',
#    '1',
#    '_',
#    'ปี',
#    'มรดก',
#    'โลก'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_ORG',
#    'O',
#    'O',
#    'B_MEA',
#    'I_MEA',
#    'E_MEA',
#    'O',
#    'B_LOC'],
#   'pred': [('ข่าว', 'O'),
#    ('ย่อย', 'O'),
#    ('_', 'O'),
#    (':', 'O'),
#    ('_', 'O'),
#    ('กัมพูชา', 'B_LOC'),
#    ('ฉลอง', 'O'),
#    ('_', 'O'),
#    ('1', 'B_NUM'),
#    ('_', 'O'),
#    ('ปี', 'E_NUM'),
#    ('มรดก', 'O'),
#    ('โลก', 'O')]},
#  {'tokens': ['พนมเปญ',
#    '-',
#    'ชาว',
#    'กัมพูชา',
#    'ฉลอง',
#    'ครบ',
#    'รอบ',
#    '_',
#    '1',
#    '_',
#    'ปี',
#    'ที่',
#    'ยูเนสโก',
#    'ขึ้น',
#    'ทะเบียน',
#    'ประสาท',
#    'พระวิหาร',
#    'เป็น',
#    'มรดก',
#    'โลก',
#    '_',
#    'มีการ',
#    'นำ',
#    'โปสเตอร์',
#    'ไป',
#    'ติดตาม',
#    'วัด',
#    '_',
#    'โรงเรียน',
#    '_',
#    'และ',
#    'สถานที่',
#    'ต่าง',
#    'ๆ',
#    '_',
#    'ทั่ว',
#    'กรุง',
#    'พนมเปญ',
#    '_',
#    'ขณะ',
#    'ที่',
#    'พระ',
#    '_',
#    'ชี',
#    '_',
#    'นักเรียน',
#    '_',
#    'และ',
#    'ครู',
#    '_',
#    'ฉลอง',
#    'กัน',
#    'ตาม',
#    'วัด',
#    'และ',
#    'โรงเรียน',
#    'ด้วย',
#    'การ',
#    'ตี',
#    'กลอง',
#    'และ',
#    'ระฆัง',
#    'ใน',
#    'เวลา',
#    '_',
#    '11.00',
#    '_',
#    'น.'],
#   'label': ['B_LOC',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_MEA',
#    'I_MEA',
#    'E_MEA',
#    'O',
#    'B_ORG',
#    'O',
#    'O',
#    'B_LOC',
#    'E_LOC',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_DTM',
#    'I_DTM',
#    'I_DTM',
#    'I_DTM',
#    'E_DTM'],
#   'pred': [('พนมเปญ', 'B_LOC'),
#    ('-', 'O'),
#    ('ชาว', 'B_ORG'),
#    ('กัมพูชา', 'E_ORG'),
#    ('ฉลอง', 'B_DES'),
#    ('ครบ', 'O'),
#    ('รอบ', 'O'),
#    ('_', 'O'),
#    ('1', 'B_NUM'),
#    ('_', 'O'),
#    ('ปี', 'E_NUM'),
#    ('ที่', 'O'),
#    ('ยูเนสโก', 'B_ORG'),
#    ('ขึ้น', 'O'),
#    ('ทะเบียน', 'O'),
#    ('ประสาท', 'O'),
#    ('พระวิหาร', 'O'),
#    ('เป็น', 'O'),
#    ('มรดก', 'O'),
#    ('โลก', 'O'),
#    ('_', 'O'),
#    ('มี', 'O'),
#    ('การ', 'O'),
#    ('นำ', 'O'),
#    ('โปสเตอร์', 'O'),
#    ('ไป', 'O'),
#    ('ติดตาม', 'O'),
#    ('วัด', 'O'),
#    ('_', 'O'),
#    ('โรงเรียน', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('สถานที่', 'O'),
#    ('ต่าง', 'O'),
#    ('ๆ', 'O'),
#    ('_', 'O'),
#    ('ทั่ว', 'O'),
#    ('กรุง', 'B_LOC'),
#    ('พนมเปญ', 'E_LOC'),
#    ('_', 'O'),
#    ('ขณะ', 'O'),
#    ('ที่', 'O'),
#    ('พระ', 'B_PER'),
#    ('_', 'O'),
#    ('ชี', 'I_PER'),
#    ('_', 'O'),
#    ('นักเรียน', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('ครู', 'O'),
#    ('_', 'O'),
#    ('ฉลอง', 'B_DES'),
#    ('กัน', 'I_DES'),
#    ('ตาม', 'O'),
#    ('วัด', 'O'),
#    ('และ', 'O'),
#    ('โรงเรียน', 'O'),
#    ('ด้วย', 'O'),
#    ('การ', 'O'),
#    ('ตี', 'O'),
#    ('กลอง', 'O'),
#    ('และ', 'O'),
#    ('ระฆัง', 'O'),
#    ('ใน', 'O'),
#    ('เวลา', 'O'),
#    ('_', 'O'),
#    ('11.00', 'B_DTM'),
#    ('_', 'O'),
#    ('น.', 'E_DTM')]},
#  {'tokens': ['นักเรียน',
#    'คน',
#    'หนึ่ง',
#    'กล่าว',
#    'ว่า',
#    '_',
#    'รู้สึก',
#    'ดีใจ',
#    'และ',
#    'ภูมิใจ',
#    'ใน',
#    'ประสาท',
#    'พระวิหาร',
#    '_',
#    'ซึ่ง',
#    'เป็น',
#    'ของ',
#    'กัมพูชา',
#    '_',
#    'และ',
#    'ไทย',
#    'ไม่',
#    'มี',
#    'สิทธิ',
#    'อ้าง',
#    'ความ',
#    'เป็น',
#    'เจ้าของ'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'E_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_ORG',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('นักเรียน', 'B_PER'),
#    ('คน', 'E_PER'),
#    ('หนึ่ง', 'B_NUM'),
#    ('กล่าว', 'O'),
#    ('ว่า', 'O'),
#    ('_', 'O'),
#    ('รู้สึก', 'O'),
#    ('ดีใจ', 'O'),
#    ('และ', 'O'),
#    ('ภูมิใจ', 'O'),
#    ('ใน', 'O'),
#    ('ประสาท', 'B_LOC'),
#    ('พระวิหาร', 'E_LOC'),
#    ('_', 'O'),
#    ('ซึ่ง', 'B_LOC'),
#    ('เป็น', 'O'),
#    ('ของ', 'O'),
#    ('กัมพูชา', 'B_LOC'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('ไทย', 'B_LOC'),
#    ('ไม่', 'O'),
#    ('มี', 'O'),
#    ('สิทธิ', 'O'),
#    ('อ้าง', 'O'),
#    ('ความ', 'O'),
#    ('เป็น', 'O'),
#    ('เจ้าของ', 'O')]},
#  {'tokens': ['ขณะ',
#    'ที่',
#    'ทหาร',
#    '_',
#    'ชาวบ้าน',
#    '_',
#    'พระ',
#    '_',
#    'และ',
#    'เจ้าหน้าที่',
#    'ประสาท',
#    'พระวิหาร',
#    '_',
#    'ก็',
#    'เฉลิมฉลอง',
#    'วาระ',
#    'นี้',
#    'เช่น',
#    'กัน'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'E_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('ขณะ', 'O'),
#    ('ที่', 'O'),
#    ('ทหาร', 'O'),
#    ('_', 'O'),
#    ('ชาวบ้าน', 'O'),
#    ('_', 'O'),
#    ('พระ', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('เจ้าหน้าที่', 'O'),
#    ('ประสาท', 'O'),
#    ('พระวิหาร', 'O'),
#    ('_', 'O'),
#    ('ก็', 'O'),
#    ('เฉลิมฉลอง', 'O'),
#    ('วาระ', 'O'),
#    ('นี้', 'O'),
#    ('เช่น', 'O'),
#    ('กัน', 'O')]},
#  {'tokens': ['อิหร่าน', 'รวบจารกรรม', 'หญิง', 'ฝรั่งเศส'],
#   'label': ['B_ORG', 'O', 'O', 'B_LOC'],
#   'pred': [('อิหร่าน', 'B_LOC'),
#    ('รวบจารกรรม', 'O'),
#    ('หญิง', 'O'),
#    ('ฝรั่งเศส', 'B_LOC')]},
#  {'tokens': ['ปารีส',
#    '-',
#    'กระทรวง',
#    'ต่าง',
#    'ประเทศ',
#    'ฝรั่งเศส',
#    'เผย',
#    'วาน',
#    'นี้',
#    '_',
#    '(',
#    '7',
#    '_',
#    'ก.ค.',
#    ')',
#    '_',
#    'ว่า',
#    '_',
#    'นัก',
#    'วิชาการ',
#    'หญิง',
#    'ฝรั่งเศส',
#    'ถูก',
#    'คุม',
#    'ตัว',
#    'ใน',
#    'อิหร่าน',
#    'เมื่อ',
#    'สัปดาห์',
#    'ที่',
#    'แล้ว',
#    '_',
#    'ใน',
#    'ข้อหา',
#    'สาย',
#    'ลับ'],
#   'label': ['B_LOC',
#    'O',
#    'B_ORG',
#    'I_ORG',
#    'I_ORG',
#    'E_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_DTM',
#    'I_DTM',
#    'E_DTM',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'B_DTM',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('ปารีส', 'B_LOC'),
#    ('-', 'O'),
#    ('กระทรวง', 'B_ORG'),
#    ('ต่าง', 'B_DES'),
#    ('ประเทศ', 'E_DES'),
#    ('ฝรั่งเศส', 'B_LOC'),
#    ('เผย', 'O'),
#    ('วาน', 'O'),
#    ('นี้', 'O'),
#    ('_', 'O'),
#    ('(', 'O'),
#    ('7', 'B_NUM'),
#    ('_', 'O'),
#    ('ก.ค.', 'B_DTM'),
#    (')', 'O'),
#    ('_', 'O'),
#    ('ว่า', 'O'),
#    ('_', 'O'),
#    ('นัก', 'B_DES'),
#    ('วิชาการ', 'E_DES'),
#    ('หญิง', 'B_DES'),
#    ('ฝรั่งเศส', 'B_LOC'),
#    ('ถูก', 'O'),
#    ('คุม', 'O'),
#    ('ตัว', 'O'),
#    ('ใน', 'B_LOC'),
#    ('อิหร่าน', 'B_LOC'),
#    ('เมื่อ', 'O'),
#    ('สัปดาห์', 'B_DTM'),
#    ('ที่', 'O'),
#    ('แล้ว', 'O'),
#    ('_', 'O'),
#    ('ใน', 'B_LOC'),
#    ('ข้อหา', 'B_DES'),
#    ('สาย', 'B_DES'),
#    ('ลับ', 'E_DES')]},
#  {'tokens': ['พร้อม',
#    'เรียกร้อง',
#    'ให้',
#    'ปล่อย',
#    'ตัว',
#    'หญิง',
#    'คน',
#    'นี้',
#    '_',
#    'เพราะ',
#    'ข้อ',
#    'กล่าวหา',
#    'ของ',
#    'อิหร่าน',
#    'ไม่',
#    'มี',
#    'มูล'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'O'],
#   'pred': [('พร้อม', 'O'),
#    ('เรียกร้อง', 'O'),
#    ('ให้', 'O'),
#    ('ปล่อย', 'O'),
#    ('ตัว', 'O'),
#    ('หญิง', 'O'),
#    ('คน', 'O'),
#    ('นี้', 'O'),
#    ('_', 'O'),
#    ('เพราะ', 'O'),
#    ('ข้อ', 'O'),
#    ('กล่าวหา', 'O'),
#    ('ของ', 'O'),
#    ('อิหร่าน', 'B_LOC'),
#    ('ไม่', 'O'),
#    ('มี', 'O'),
#    ('มูล', 'O')]},
#  {'tokens': ['โดย',
#    'หญิง',
#    'คน',
#    'นี้',
#    'อยู่',
#    'ใน',
#    'อิหร่าน',
#    'มา',
#    '_',
#    '5',
#    '_',
#    'เดือน',
#    'แล้ว',
#    '_',
#    'และ',
#    'กำลัง',
#    'จะ',
#    'เดินทาง',
#    'ออก',
#    'นอก',
#    'ประเทศ',
#    '_',
#    'แต่',
#    'ถูก',
#    'จับ',
#    'ก่อน'],
#   'label': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_LOC',
#    'O',
#    'O',
#    'B_MEA',
#    'O',
#    'B_MEA',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('โดย', 'O'),
#    ('หญิง', 'O'),
#    ('คน', 'O'),
#    ('นี้', 'O'),
#    ('อยู่', 'O'),
#    ('ใน', 'O'),
#    ('อิหร่าน', 'B_LOC'),
#    ('มา', 'O'),
#    ('_', 'O'),
#    ('5', 'B_NUM'),
#    ('_', 'O'),
#    ('เดือน', 'E_NUM'),
#    ('แล้ว', 'O'),
#    ('_', 'O'),
#    ('และ', 'O'),
#    ('กำลัง', 'O'),
#    ('จะ', 'O'),
#    ('เดินทาง', 'O'),
#    ('ออก', 'O'),
#    ('นอก', 'O'),
#    ('ประเทศ', 'B_LOC'),
#    ('_', 'O'),
#    ('แต่', 'O'),
#    ('ถูก', 'O'),
#    ('จับ', 'O'),
#    ('ก่อน', 'O')]},
#  {'tokens': ['โครเอเชีย', 'ได้', 'นายก', 'ฯ', '_', 'หญิง', 'คน', 'แรก'],
#   'label': ['B_ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'pred': [('โครเอเชีย', 'O'),
#    ('ได้', 'O'),
#    ('นายก', 'B_TTL'),
#    ('ฯ', 'O'),
#    ('_', 'I_TTL'),
#    ('หญิง', 'I_TTL'),
#    ('คน', 'O'),
#    ('แรก', 'O')]},
#  {'tokens': ['ซาเกรบ',
#    '-',
#    'นาง',
#    'จาดรันกา',
#    '_',
#    'โคซอร์',
#    '_',
#    'ขึ้น',
#    'รับ',
#    'ตำแหน่ง',
#    'นายก',
#    'รัฐมนตรี',
#    'หญิง',
#    'คน',
#    'แรก',
#    'ของ',
#    'โครเอเชีย',
#    '_',
#    'พร้อม',
#    'รับปาก',
#    'จะ',
#    'พยายาม',
#    'ให้',
#    'โครเอเชีย',
#    'ได้',
#    'เข้า',
#    'เป็น',
#    'สมาชิก',
#    'สหภาพ',
#    'ยุโรป',
#    'และ',
#    'จะ',
#    'พยายาม',
#    'แก้ไข',
#    'วิกฤติ',
#    'เศรษฐกิจ'],
#   'label': ['B_LOC',
#    'O',
#    'B_TTL',
#    'B_PER',
#    'I_PER',
#    'E_PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B_ORG',
#    'E_ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'pred': [('ซาเกรบ', 'B_LOC'),
#    ('-', 'O'),
#    ('นาง', 'B_TTL'),
#    ('จาดรันกา', 'B_PER'),
#    ('_', 'I_PER'),
#    ('โคซอร์', 'E_PER'),
#    ('_', 'O'),
#    ('ขึ้น', 'O'),
#    ('รับ', 'O'),
#    ('ตำแหน่ง', 'O'),
#    ('นายก', 'B_TTL'),
#    ('รัฐมนตรี', 'B_TTL'),
#    ('หญิง', 'O'),
#    ('คน', 'O'),
#    ('แรก', 'O'),
#    ('ของ', 'B_LOC'),
#    ('โครเอเชีย', 'E_LOC'),
#    ('_', 'O'),
#    ('พร้อม', 'O'),
#    ('รับปาก', 'O'),
#    ('จะ', 'O'),
#    ('พยายาม', 'O'),
#    ('ให้', 'O'),
#    ('โครเอเชีย', 'B_LOC'),
#    ('ได้', 'O'),
#    ('เข้า', 'O'),
#    ('เป็น', 'O'),
#    ('สมาชิก', 'O'),
#    ('สหภาพ', 'B_ORG'),
#    ('ยุโรป', 'E_ORG'),
#    ('และ', 'O'),
#    ('จะ', 'O'),
#    ('พยายาม', 'O'),
#    ('แก้ไข', 'O'),
#    ('วิกฤติ', 'B_TRM'),
#    ('เศรษฐกิจ', 'B_TRM')]},
#  {'tokens': ['นาง',
#    'โคซอร์',
#    'เป็น',
#    'นักข่าว',
#    'ที่',
#    'ผัน',
#    'ตัว',
#    'ไป',
#    'เล่น',
#    'การเมือง'],
#   'label': ['B_TTL', 'B_PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'pred': [('นาง', 'B_TTL'),
#    ('โคซอร์', 'B_PER'),
#    ('เป็น', 'O'),
#    ('นักข่าว', 'B_DES'),
#    ('ที่', 'O'),
#    ('ผัน', 'O'),
#    ('ตัว', 'O'),
#    ('ไป', 'O'),
#    ('เล่น', 'O'),
#    ('การเมือง', 'B_TRM')]}]

# %%
from seqeval.metrics import classification_report

labels = []
preds = []

for ele in results: 
    l = [item.replace("_", "-") for item in ele["label"]]
    p = [item[1].replace("_", "-") for item in ele["pred"]]
    if len(p) != len(l):
        n = min(len(p), len(l))
        p = p[:n]
        l = l[:n]
    labels.append(l)
    preds.append(p)
report = classification_report(labels, preds)
# print(report)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          BRN       0.00      0.00      0.00         0
#          DES       0.00      0.00      0.00        26
#          DTM       0.11      0.15      0.12        26
#          LOC       0.24      0.39      0.30       105
#          MEA       0.06      0.02      0.03        58
#          NUM       0.10      0.33      0.15        18
#          ORG       0.23      0.21      0.22        85
#          PER       0.23      0.36      0.28        56
#          TRM       0.00      0.00      0.00         1
#          TTL       0.36      0.51      0.42        41
#
#    micro avg       0.19      0.27      0.22       416
#    macro avg       0.13      0.20      0.15       416
# weighted avg       0.20      0.27      0.22       416

# %%
dataset = load_dataset("nakhun/thaisum", split="test")
# Out:
# Using the latest cached version of the module from C:\Users\isada\.cache\huggingface\modules\datasets_modules\datasets\nakhun--thaisum\347b33c852af4d796e1224e00e15142d626608a9fa3e07ad6d19dfd8fcae5423 (last modified on Sat Aug 31 23:11:18 2024) since it couldn't be found locally at nakhun/thaisum, or remotely on the Hugging Face Hub.

# %%
prompt_ts = """\
"Summarize the key points from the following news article, focusing on the most important events and opinions expressed. Aim for a clear, concise summary that captures the core message of the article. Exclude any irrelevant details."

---

Example Input:
Title: ฟลอเรส รับ วัตฟอร์ดห่วยเองเกมพ่ายพาเลซคาบ้าน
Body: กีเก ซานเชซ ฟลอเรส\xa0 กุนซือเลือดกระทิงของทีมวัตฟอร์ด\xa0 เมินประเด็นจุดโทษปัญหาในเกมพรีเมียร์ลีก อังกฤษ นัดที่แตนอาละวาดเปิดบ้านพ่าย คริสตัล พาเลซ 0-1ชี้ทีมของเขาเล่นไม่ดีพอเอง,สำนักข่าวต่างประเทศรายงานวันที่ 27 ก.ย. ว่า กีเก ซานเชซ ฟลอเรส\xa0 ผู้จัดการทีมชาวสเปน ของ แตนอาละวาด วัตฟอร์ด\xa0 ยอมรับทีมของเขาเล่นได้ไม่ดีพอเอง ในเกมพรีเมียร์ลีก อังกฤษ นัดเปิดบ้านพ่าย อินทรีผงาด คริสตัล พาเลซ 0-1 เมื่อคืนวันอาทิตย์ที่ผ่านมา,เกมนี้จุดเปลี่ยนมาอยู่ที่การได้จุดโทษในช่วงครึ่งหลังของ คริสตัล พาเลซ ซึ่งไม่ค่อยชัดเจนเท่าไหร่ว่า อัลลัน นียอม นั้นไปทำฟาล์วใส่ วิลฟรีด ซาฮา ในเขตโทษหรือไม่ แต่ผู้ตัดสินก็ชี้เป็นจุดโทษ ซึ่ง โยอัน กาบาย สังหารไม่พลาด และเป็นประตูชัยช่วยให้ คริสตัล พาเลซ เอาชนะ วัตฟอร์ด ไป 1-0 และเป็นการพ่ายแพ้ในบ้านนัดแรกของวัตฟอร์ดในฤดูกาลนี้อีกด้วย,ฟลอเรส กล่าวว่า มันเป็นเรื่องยากในการหยุดเกมรุกของคริสตัล พาเลซ ซึ่งมันอึดอัดจริงๆสำหรับเรา เราเล่นกันได้ไม่ดีนักในตอนที่ได้ครองบอล เราต้องเล่นทางริมเส้นให้มากกว่านี้ เราไม่สามารถหยุดเกมสวนกลับของพวกเขาได้ และแนวรับของเราก็ยืนไม่เป็นระเบียบสักเท่าไหร่ในช่วงครึ่งแรก ส่วนเรื่องจุดโทษการตัดสินใจขั้นสุดท้ายมันอยู่ที่ผู้ตัดสิน ซึ่งมันเป็นการตัดสินใจที่สำคัญ ผมเองก็ไม่รู้ว่าเขาตัดสินถูกหรือเปล่า บางทีมันอาจเป็นจุดที่ตัดสินเกมนี้เลย แต่เราไม่ได้แพ้เกมนี้เพราะจุดโทษ เราแพ้ในวันนี้เพราะเราเล่นไม่ดีและคริสตัล พาเลซ เล่นดีกว่าเรา เราไม่ได้มีฟอร์มการเล่นที่ดีในเกมนี้เลย

Expected Output:
Summary: กีเก ซานเชซ ฟลอเรส  กุนซือเลือดกระทิงของทีมวัตฟอร์ด  เมินประเด็นจุดโทษปัญหาในเกมพรีเมียร์ลีก อังกฤษ นัดที่แตนอาละวาดเปิดบ้านพ่าย คริสตัล พาเลซ 0-1ชี้ทีมของเขาเล่นไม่ดีพอเอง

---

Title: {}
Body: {}
Summary:
"""

# %%
import ast

results = []

ds = dataset.select(range(20))

for item in tqdm(ds, total=len(ds)):
    try:
        response = gemini.inference(prompt=prompt_ts.format(item["title"], item["body"]))
        results.append({
            "title": item["title"],
            "body": item["body"],
            "gold": item["summary"],
            "generation": response,
            "tags" : item["tags"],
            "url" : item["url"],
        })
    except KeyError:
        pass
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [02:05<00:00,  6.25s/it]

# %%
results[16]
# Out:
# {'title': 'ศรีลังกาสลด น้ำท่วม-ดินโคลนถล่มหลังฝนตกหนัก ตายแล้วเกือบครึ่งร้อย',
#  'body': 'เกิดเหตุดินโคลนถล่มลงมาจากภูเขา หลังฝนตกหนักติดต่อนาน 3 วันในศรีลังกา ถมทับบ้านกว่า 200 หลังใน 3 หมู่บ้าน พบเหยื่อเคราะห์ร้ายแล้ว 13 ราย ทีมกู้ภัยกำลังเร่งค้นหาชาวบ้านที่ยังติดอยู่ใต้ดินโคลนอีกจำนวนมาก ขณะที่มีคนเสียชีวิตจากน้ำท่วม อีก 32 ราย,เมื่อวันที่ 18 พ.ค.59 สำนักข่าวบีบีซี รายงานเกิดเหตุดินโคลนถล่มลงมาจากภูเขาเนื่องจากมีฝนตกหนักติดต่อหลายวัน ในศรีลังกา ถมทับบ้านเรือนประชาชนกว่า 200 หลังใน 3 หมู่บ้าน ของอำเภอคีกัลลี ทางภาคกลางของประเทศ โดยเจ้าหน้าที่กู้ภัยกำลังเร่งค้นหาเหยื่อเคราะห์ร้ายจำนวนหนึ่งที่ติดอยู่ใต้ดินโคลน ขณะที่พบศพผู้เสียชีวิตแล้วอย่างน้อย 13 ราย,เจ้าหน้าที่ศรีลังกา เปิดเผยว่า ทีมกู้ภัยสามารถช่วยเหลือประชาชนที่ประสบเหตุดินโคลนถล่มลงมาจากภูเขาถมทับบ้านเรือนใน 3 หมู่บ้าน ได้แก่ หมู่บ้านศิริปุระ, ปัลลีบากี และอีลากิปิตยา ออกมาได้แล้วประมาณ 150 คน แต่ยังคงมีบ้านอีกกว่า 60 หลังที่ถูกดินโคลนทับถมสูง ส่วนสถานการณ์น้ำท่วมในศรีลังกา หลังจากเกิดฝนตกหนักต่อเนื่องติดต่อนานถึง 3 วัน ทำให้มีผู้เสียชีวิตแล้วอย่างน้อย 32 ราย ขณะที่มีประชาชนเกือบ 350,000 คนได้รับผลกระทบจากน้ำท่วมครั้งใหญ่ในประเทศ',
#  'gold': 'เกิดเหตุดินโคลนถล่มลงมาจากภูเขา หลังฝนตกหนักติดต่อนาน 3 วันในศรีลังกา ถมทับบ้านกว่า 200 หลังใน 3 หมู่บ้าน พบเหยื่อเคราะห์ร้ายแล้ว 13 ราย ขณะที่ทีมกู้ภัยกำลังเร่งค้นหาชาวบ้านที่ยังติดอยู่ใต้ดินโคลนอีกจำนวนมาก ',
#  'generation': 'ศรีลังกาพบผู้เสียชีวิตเกือบ 50 รายจากดินโคลนถล่มและน้ำท่วม หลังฝนตกหนัก 3 วัน ดินถล่มถมทับบ้านกว่า 200 หลังใน 3 หมู่บ้าน มีผู้ติดอยู่ใต้ดินโคลนจำนวนมาก ทีมกู้ภัยเร่งค้นหา ขณะที่มีผู้เสียชีวิตจากน้ำท่วมอีก 32 ราย',
#  'tags': 'ศรีลังกา,ศรีลังกาสลด,ดินโคลนถล่ม,น้ำท่วม,ฝนตกหนัก,เสียชีวิต,เหยื่อดินโคลนถล่ม,ข่าว,ไทยรัฐออนไลน์,ข่าวต่างประเทศ',
#  'url': 'https://www.thairath.co.th/content/622310'}

# %%
predictions = [r["generation"] for r in results]
references = [r["gold"] for r in results]

# %%
references
# Out:
# ['มีชัย ไม่ยี่หระเสียงค้านชงสูตรพิสดารเลือกตั้ง ส.ส. ประกาศ ผลช้าไปชั่วโมงสองชั่วโมงไม่เห็นเป็นไร แสลงหูชื่อ สมชัย ชิ่งหนีดื้อๆ พรเพชร ให้นายกฯ ตัดสินใจปลดล็อกพรรคการเมือง',
#  'กีเก ซานเชซ ฟลอเรส  กุนซือเลือดกระทิงของทีมวัตฟอร์ด  เมินประเด็นจุดโทษปัญหาในเกมพรีเมียร์ลีก อังกฤษ นัดที่แตนอาละวาดเปิดบ้านพ่าย คริสตัล พาเลซ 0-1ชี้ทีมของเขาเล่นไม่ดีพอเอง',
#  'เนปาลระทึก หลังเกิดพายุฝนฟ้าคะนองถล่มทางใต้ สร้างความเสียหายหลายหมู่บ้าน เบื้องต้นพบผู้เสียชีวิตแล้ว 30 ศพ บาดเจ็บ 400 ราย ระบบสาธารณูปโภคพังพินาศ',
#  'เป็นศูนย์รวมของความคิดสร้างสรรค์และคอมมูนิตี้คนรุ่นใหม่ ล่าสุด อุสรา ยงปิยะกุล คว้าศิลปินไทยรุ่นใหม่จากนิวยอร์ก กันตภณ เมธีกุล มาร่วมคอลลาโบเรชั่น สินค้าลิมิเต็ด อิดิชั่น  ODS X GONGKAN',
#  'สหประชาชาติประเมินว่า สังคมเมียนมากำลังก้าวเข้าสู่สังคมผู้สูงอายุ ประชากรเมียนมากว่า 9% มีอายุมากกว่า 65 ปีขึ้นไป เเละจะเพิ่มสูงขึ้นเป็น 25% ภายในปี 2050บ้านตะวันลับ Twilight Villa ถูกจัดตั้งขึ้นในปี 2010 เพื่อแก้ไขปัญหาผู้สูงอายุที่ถูกทอดทิ้งเพิ่มมากขึ้นในสังคมเมียนมา ปัจจุบันมีผู้พักอาศัยอยู่ในบ้านหลังนี้ราว 120 คน ส่วนใหญ่มีอายุ 70 ปีขึ้นไป แต่เนื่องจากพื้นที่ของบ้านมีขนาดไม่ใหญ่มาก จึงทำให้มีผู้สูงอายุต้องรอการเข้าพักอาศัยกว่า 100 คน',
#  'ยังไม่มาเก็บ ชาวชุมชนเคหะร่มเกล้า 52 ถนนเคหะร่มเกล้า แขวงคลองสองต้นนุ่น เขต ลาดกระบัง แจ้งว่า ก่อนหน้านี้ทาง สนง.เขตลาดกระบัง ชี้แจงว่า ได้เข้าไปจัดเก็บ ขยะในชุมชนเรียบร้อยแล้ว',
#  'ฝุ่นละออง PM2.5 หรือฝุ่นจิ๋ว มีฤทธิ์ทะลวงปอด ฉีดน้ำแล้วก็ยังไม่ไปไหน อยู่ต่ออีกหลายวัน ถ้าหาต้นเหตุไม่เจอ ฝุ่นกทม.เกิดทุกปี ไม่ใช่ 3 ปีรอรถไฟฟ้าสร้างเสร็จอย่างที่บางคนบอก',
#  'ผอ.รพ.สวนปรุง แนะ ประชาชนติดตามข่าวค้นหา 13 ชีวิตติดถ้ำ เผื่อใจทุกผลลัพธ์ทั้งบวกและลบ เลือกติดตามข่าวจากแหล่งข่าวน่าเชื่อถือ ไม่จดจ่อข่าวติดต่อกันเกิน 2 ชั่วโมง  ด้าน กรมสุขภาพจิต เผย หลัง',
#  'ตำรวจทุ่งสองห้อง ส่งสำนวนชันสูตรศพ ธวัชชัย อนุกูล อดีตเจ้าหน้าที่ที่ดิน จ.พังงา ผู้ต้องหาเสียชีวิตในห้องขังดีเอสไอ ถึงมืออัยการแล้ว เผยข้อสรุป มีผู้ทำให้ตาย ด้าน รองอธิบดีอัยการคดีอาญา ระบุ ต้องยื่นคำร้องตามกฎหมายใน 30วัน',
#  'สยามเทค สั่งพักการเรียนนักศึกษา 12 คน พร้อมภาคทัณฑ์ กรณีคลิปรับน้องฉาวจุดไฟลนก้น และให้เคี้ยวข้าวป้อนกัน เผยเด็กยอมรับผิดไม่ได้ขออนุญาตสถาบัน แต่แอบไปกันเอง เลขาธิการ กช.ชี้ไม่มีกฎหมายเอาผิดบรรดารุ่นพี่ที่สำเร็จการศึกษาไป',
#  'ปีเตอร์ เช็ก นายทวารก้านยาวของทีมปืนโต ออกโรงยืนยันความสัมพันธ์ส่วนตัวระหว่างเขากับ โชเซ มูรินโญ นายใหญ่ของทีมเชลซี ยังเหมือนเดิม แม้จะย้ายข้ามฟากมาร่วมทีมคู่ปรับร่วมกรุงลอนดอนอย่าง อาร์เซนอล ก็ตาม',
#  ' ในรอบหนึ่งทศวรรษที่ผ่านมาวิกฤตการเมืองไทยตกอยู่ในกับดักแห่งวาทกรรม คนดี – คนชั่ว ทั้งโดยเปิดเผยและแอบแฝง จนดูเหมือนประเทศนี้จะเป็นประชาธิปไตย',
#  'ม็อบจุฬาฯ คนแน่น ยุติชุมนุมแล้ว แกนนำจัดกิจกรรมแบบแฟลชม็อบ ประณามหมายจับ เพนกวิน พร้อมนัดร่วมชุมนุม 16 ส.ค. ที่อนุสาวรีย์ประชาธิปไตย ',
#  'แพทย์ระบุหลายปัจจัยมีผลต่อการหลั่งฮอร์โมนในสมองเด็ก ย้ำความเชื่อเก่า ฮอร์โมนในไก่ ทำให้เด็กมีภาวะโตเร็ว ด้านสัตวแพทย์ย้ำเทคโนโลยีพัฒนาสายพันธุ์ไก่ตามธรรมชาติช่วยอัตราเติบโตของไก่เร็วขึ้น การันตีไก่ไทยไม่ใช้ฮอร์โมน ',
#  'ตร.สหรัฐฯ พบศพหญิงตั้งครรภ์และลูกสาว 2 คนถูกสามีฆ่า ก่อนนำศพมายัดถังน้ำมันของโรงงานที่ทำงานอยู่ เพื่อป้องกันไม่ให้กลิ่นโชยออกมา ขณะที่อัยการเตรียมสั่งฟ้องสามีโหดรายนี้แล้ว ในข้อหาก่อฆาตกรรม',
#  'คนเลี้ยงวัวผงะ วัวเพศผู้ตัวใหญ่หายไปจากคอกข้ามคืน ออกตามหา  เช้าไปเจอแทบช็อกพบ คนร้ายขโมยไปฆ่า ตัดขา ตัดหาง ตัดใบหูตัดอวัยวะเพศตัวเดียวอันเดียว ใส่กระสอบทิ้งไว้ในป่า คาดฝีมือ แก๊งดมกาว',
#  'เกิดเหตุดินโคลนถล่มลงมาจากภูเขา หลังฝนตกหนักติดต่อนาน 3 วันในศรีลังกา ถมทับบ้านกว่า 200 หลังใน 3 หมู่บ้าน พบเหยื่อเคราะห์ร้ายแล้ว 13 ราย ขณะที่ทีมกู้ภัยกำลังเร่งค้นหาชาวบ้านที่ยังติดอยู่ใต้ดินโคลนอีกจำนวนมาก ',
#  'เอนเนอจี ไชน่า บิ๊กธุรกิจพลังงานจีนจับมือบีกริม ทุ่มงบ 3,600 ล้านบาท ลงทุนโรงไฟฟ้าไฮบริด ป้อนระบบไฟฟ้าให้สนามบินอู่ตะเภา สมคิด จับเข่าเห่กล่อมชวนให้ลงทุนในอีอีซีเพิ่ม',
#  'ทำไมหมูแพง แม่ค้า พ่อค้า เขียงหมูบ่นอุบ หน้าโรงเชือด หน้าฟาร์มราคาสูง ทำราคาหมูสามชั้นแตะกิโลกรัมละ 180 บาท พบ 2 ปัจจัยหลักทำราคาพุ่ง',
#  'เจ้าหน้าที่กรมควบคุมโรค นำรถเก็บตัวอย่างชีวนิรภัยพระราชทาน เข้าตรวจคัดกรองที่คอนโดมิเนียมซอยสุขุมวิท 26 หลังพบเด็กหญิงวัย 9 ขวบ ชาวซูดาน เดินทางมากับคณะทูต ติดโควิด-19 ยืนยันผู้ป่วย']

# %%
import evaluate

# Load ROUGE and BLEU metrics
rouge = evaluate.load("rouge")
bleu = evaluate.load("bleu")

# %%
rouge_result
# Out:
# {'rouge1': np.float64(0.36777777777777776),
#  'rouge2': np.float64(0.2369047619047619),
#  'rougeL': np.float64(0.36333333333333334),
#  'rougeLsum': np.float64(0.3733333333333333)}

# %%
# !pip install attacut
# Out:
# Collecting attacut
#   Using cached attacut-1.0.6-py3-none-any.whl.metadata (4.0 kB)
# Collecting docopt>=0.6.2 (from attacut)
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Collecting fire>=0.1.3 (from attacut)
#   Using cached fire-0.6.0-py2.py3-none-any.whl
# Collecting nptyping>=0.2.0 (from attacut)
#   Using cached nptyping-2.5.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from attacut) (2.0.1)
# Requirement already satisfied: pyyaml>=5.1.2 in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from attacut) (6.0.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from attacut) (1.16.0)
# Collecting ssg>=0.0.4 (from attacut)
#   Using cached ssg-0.0.8-py3-none-any.whl.metadata (762 bytes)
# Requirement already satisfied: torch>=1.2.0 in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from attacut) (2.4.1)
# Collecting termcolor (from fire>=0.1.3->attacut)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting numpy>=1.17.0 (from attacut)
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Collecting python-crfsuite>=0.9.6 (from ssg>=0.0.4->attacut)
#   Using cached python_crfsuite-0.9.10-cp311-cp311-win_amd64.whl.metadata (4.3 kB)
# Requirement already satisfied: tqdm>=4.32.2 in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from ssg>=0.0.4->attacut) (4.66.5)
# Requirement already satisfied: filelock in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from torch>=1.2.0->attacut) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from torch>=1.2.0->attacut) (4.11.0)
# Requirement already satisfied: sympy in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from torch>=1.2.0->attacut) (1.13.2)
# Requirement already satisfied: networkx in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from torch>=1.2.0->attacut) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from torch>=1.2.0->attacut) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from torch>=1.2.0->attacut) (2024.6.1)
# Requirement already satisfied: colorama in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from tqdm>=4.32.2->ssg>=0.0.4->attacut) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from jinja2->torch>=1.2.0->attacut) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\isada\miniconda3\envs\eval2\lib\site-packages (from sympy->torch>=1.2.0->attacut) (1.3.0)
# Using cached attacut-1.0.6-py3-none-any.whl (1.3 MB)
# Using cached nptyping-2.5.0-py3-none-any.whl (37 kB)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Using cached ssg-0.0.8-py3-none-any.whl (473 kB)
# Using cached python_crfsuite-0.9.10-cp311-cp311-win_amd64.whl (155 kB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Installing collected packages: python-crfsuite, docopt, termcolor, numpy, nptyping, fire, ssg, attacut
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.1
#     Uninstalling numpy-2.0.1:
#       Successfully uninstalled numpy-2.0.1
# Successfully installed attacut-1.0.6 docopt-0.6.2 fire-0.6.0 nptyping-2.5.0 numpy-1.26.4 python-crfsuite-0.9.10 ssg-0.0.8 termcolor-2.4.0

# %%
# from attacut import tokenize, Tokenizer

# %%
preds = [" ".join(tokenize(p)) for p in predictions]
refs = [" ".join(tokenize(r)) for r in references]

# Compute ROUGE scores
rouge_result = rouge.compute(predictions=preds, references=refs, use_aggregator=True)

# Compute BLEU scores
bleu_result = bleu.compute(
    predictions=preds,
    references=refs,
    )

# %%
rouge_result
# Out:
# {'rouge1': np.float64(0.36777777777777776),
#  'rouge2': np.float64(0.2369047619047619),
#  'rougeL': np.float64(0.36333333333333334),
#  'rougeLsum': np.float64(0.3733333333333333)}

# %%
bleu_result
# Out:
# {'bleu': 0.10381817605179183,
#  'precisions': [0.22724338282763074,
#   0.12034009156311315,
#   0.07620941020543406,
#   0.05574210879785091],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.7003293084522502,
#  'translation_length': 1549,
#  'reference_length': 911}
